# %% [markdown]
# ## OSU DS4S Data Science Club
# ### RNASeq Workflow
#
# 1. Setup Environment
# 1. Download SRA Files
# 1. Convert SRA to fastq
# 1. Index Genome
# 1. Run fastQC
# 1. Run trim_galore
# 1. Align Reads
# 1. Run FeatureCounts on each file
# 1. Combine counts
# 1. Run multiqc
# 1. Display html links for QC

# %%
import subprocess
import os
import glob
from multiprocessing import Process, current_process, Pool


# reusable function to run cmd, pipe stdout to console
# and return std out back for error checking

def run_cmd(cmd):
    p = subprocess.Popen(cmd,
                     stdout=subprocess.PIPE,
                     stderr=subprocess.STDOUT,shell=True)
    output = ""
    while True:
        line = p.stdout.readline().decode(encoding='UTF-8')
        if not line:
            break
        print (line.strip())
        output = output + line
    return output

# %%
MAXCORES = '24'
ENVCMD = "source activate rnaseq"
FASTQS = 'fastqs'
TFASTQS = 'trimmed_fastqs'
PFASTQS = 'paired_fastqs'
TPFASTQS = 'trimmed_paired_fastqs'
FASTQCOUT = 'fastQC_output'
TFASTQCOUT = 'trimmed_fastQC_output'
STARDIR = './star_output'
FCDIR = './featureCount_output'

# MAX CPUS For Owens should be 24 (28 possible but reserve a few for interactivity)
os.environ['MAXCORES'] = '24'

# Set Working Directory
os.environ['WORKDIR'] = os.getcwd()

# Set sra_toolkit cfg location.  Needed to overide default download directory
# Will default to data directory in the current working directory.
os.environ['VDB_CONFIG'] = os.path.expandvars("$WORKDIR/sra_toolkit.kfg")

# The data download directories
os.environ['DATA'] =  os.path.expandvars("$WORKDIR/data/sra")

# The results directories
os.environ['FASTQS'] = 'fastqs'
os.environ['TFASTQS'] = 'trimmed_fastqs'
os.environ['PFASTQS'] = 'paired_fastqs'
os.environ['TPFASTQS'] = 'trimmed_paired_fastqs'
os.environ['FASTQCOUT'] = 'fastQC_output'
os.environ['TFASTQCOUT'] = 'trimmed_fastQC_output'
os.environ['STARDIR'] = './star_output'
os.environ['FCDIR'] = './featureCount_output'

# The binary directories
os.environ['BASEDIR'] = '/fs/project/PAS1307'
os.environ['BINDIR'] = os.path.expandvars("$BASEDIR/bin")
os.environ['SRABINDIR'] = os.path.expandvars("$BASEDIR/bin/sratoolkit.2.8.2-1-ubuntu64/bin")
os.environ['TGBINDIR'] = os.path.expandvars("$BASEDIR/bin/trim_galore")

# The Genome directories
os.environ['GENOMEDIR'] = os.path.expandvars("$BASEDIR/genomes")
#os.environ['GENOME'] = 'Drosophila_melanogaster/Ensembl/BDGP5.25/'         
os.environ['GENOME'] = 'Mus_musculus/Ensembl/GRCm38' 
os.environ['WHOLEGENOMEDIR'] = os.path.expandvars("$GENOMEDIR/$GENOME/Sequence/WholeGenomeFasta")
os.environ['GENEANNOTATIONDIR'] = os.path.expandvars("$GENOMEDIR/$GENOME/Annotation/Genes")
os.environ['STARGENOMEDIR'] = os.path.expandvars("$GENOMEDIR/$GENOME/Sequence/StarIndex")

# %%
cmd = '''
mkdir -p $FASTQS
mkdir -p $PFASTQS
mkdir -p $FASTQCOUT
mkdir -p $STARDIR
mkdir -p $FCDIR
mkdir -p $TFASTQS
mkdir -p $TPFASTQS
mkdir -p $TFASTQCOUT
'''

out = run_cmd(cmd)

# %%
cmd = '''
$SRABINDIR/prefetch --option-file $WORKDIR/SraAccList.txt
'''
out = run_cmd(cmd)
# Out:
# 2018-01-26T13:32:32 prefetch.2.8.2: 1) 'ERR899429' is found locally
#
# 2018-01-26T13:32:32 prefetch.2.8.2: 2) 'ERR899433' is found locally
#
# 2018-01-26T13:32:33 prefetch.2.8.2: 3) 'ERR899427' is found locally
#
# 2018-01-26T13:32:33 prefetch.2.8.2: 4) 'ERR899421' is found locally
#
# 2018-01-26T13:32:33 prefetch.2.8.2: 5) 'ERR899425' is found locally
#
# 2018-01-26T13:32:33 prefetch.2.8.2: 6) 'ERR899435' is found locally
#
# 2018-01-26T13:32:33 prefetch.2.8.2: 7) 'ERR899430' is found locally
#
# 2018-01-26T13:32:33 prefetch.2.8.2: 8) 'ERR899432' is found locally
#
# 2018-01-26T13:32:34 prefetch.2.8.2: 9) 'ERR899431' is found locally
#
# 2018-01-26T13:32:34 prefetch.2.8.2: 10) 'ERR899434' is found locally
#
# 2018-01-26T13:32:34 prefetch.2.8.2: 11) 'ERR899438' is found locally
#
# 2018-01-26T13:32:34 prefetch.2.8.2: 12) 'ERR899422' is found locally
#
# 2018-01-26T13:32:34 prefetch.2.8.2: 13) 'ERR899423' is found locally
#
# 2018-01-26T13:32:34 prefetch.2.8.2: 14) 'ERR899424' is found locally
#
# 2018-01-26T13:32:35 prefetch.2.8.2: 15) 'ERR899428' is found locally
#
# 2018-01-26T13:32:35 prefetch.2.8.2: 16) 'ERR899426' is found locally
#
# 2018-01-26T13:32:35 prefetch.2.8.2: 17) 'ERR899437' is found locally
#
# 2018-01-26T13:32:35 prefetch.2.8.2: 18) 'ERR899436' is found locally

# %%
cmd = '''
## Make STAR index if not exists
if [ ! -d "$STARGENOMEDIR/" ]; then
    echo "STAR index does not exist, building STAR index"

    mkdir $STARGENOMEDIR

    $BINDIR/STAR \
        --runThreadN $MAXCORES \
        --runMode genomeGenerate \
        --genomeDir $STARGENOMEDIR \
        --genomeFastaFiles $WHOLEGENOMEDIR/genome.fa \
        --sjdbGTFfile $GENEANNOTATIONDIR/genes.gtf \
        --sjdbOverhang 100
fi
'''
out = run_cmd(cmd)

# %%
cmd = '''
is_paired() {
    # function to examine whether a .sra file is paired-end sequencing
    # ref: https://www.biostars.org/p/139422/
    local SRA="$1"
    local x=$(
        $SRABINDIR/fastq-dump -I -X 1 -Z --split-spot "$SRA" 2>/dev/null \
        | awk '{if(NR % 2 == 1) print substr($1,length($1),1)}' \
        | uniq \
        | wc -l
    )
    # echo $SRA $x
    # $x should be 2 if paired-end, 1 if single-end
    if [ $x == 2 ]; then
        return 0 # true
    else
        return 1 # false
    fi
}

dump_sra() {
    # function to dump sra to fastq file with auto-detecting
    # whether reads are from single-end or paired-end
    local sra="$1"
    echo $sra
    echo $SRABINDIR
    if is_paired $sra; then
        echo "$sra is detected as paired-end sequencing reads"
        # Note that paired-end sequencing reads should be dumped into two fastq files
        $SRABINDIR/fastq-dump --gzip -I --split-files -O paired_fastqs "$sra"
    else
        echo "$sra is detected as single-end sequencing reads"
        $SRABINDIR/fastq-dump --gzip -O fastqs "$sra"
    fi
}


## Dump .sra to .fastq
echo "Dumping .sra files to .fastq.gz files"

## Dump in parallel using xargs
export -f is_paired
export -f dump_sra

find $DATA/*.sra | xargs --max-args=1 --max-procs=$MAXCORES -I {} bash -c 'dump_sra "$@"' _ {}
'''
out = run_cmd(cmd)
# Out:
# Dumping .sra files to .fastq.gz files
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899421.sra
# /fs/project/PAS1307/bin/sratoolkit.2.8.2-1-ubuntu64/bin
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899422.sra
# /fs/project/PAS1307/bin/sratoolkit.2.8.2-1-ubuntu64/bin
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899423.sra
# /fs/project/PAS1307/bin/sratoolkit.2.8.2-1-ubuntu64/bin
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899424.sra
# /fs/project/PAS1307/bin/sratoolkit.2.8.2-1-ubuntu64/bin
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899425.sra
# /fs/project/PAS1307/bin/sratoolkit.2.8.2-1-ubuntu64/bin
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899426.sra
# /fs/project/PAS1307/bin/sratoolkit.2.8.2-1-ubuntu64/bin
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899427.sra
# /fs/project/PAS1307/bin/sratoolkit.2.8.2-1-ubuntu64/bin
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899428.sra
# /fs/project/PAS1307/bin/sratoolkit.2.8.2-1-ubuntu64/bin
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899429.sra
# /fs/project/PAS1307/bin/sratoolkit.2.8.2-1-ubuntu64/bin
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899430.sra
# /fs/project/PAS1307/bin/sratoolkit.2.8.2-1-ubuntu64/bin
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899431.sra
# /fs/project/PAS1307/bin/sratoolkit.2.8.2-1-ubuntu64/bin
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899432.sra
# /fs/project/PAS1307/bin/sratoolkit.2.8.2-1-ubuntu64/bin
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899433.sra
# /fs/project/PAS1307/bin/sratoolkit.2.8.2-1-ubuntu64/bin
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899434.sra
# /fs/project/PAS1307/bin/sratoolkit.2.8.2-1-ubuntu64/bin
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899435.sra
# /fs/project/PAS1307/bin/sratoolkit.2.8.2-1-ubuntu64/bin
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899436.sra
# /fs/project/PAS1307/bin/sratoolkit.2.8.2-1-ubuntu64/bin
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899437.sra
# /fs/project/PAS1307/bin/sratoolkit.2.8.2-1-ubuntu64/bin
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899438.sra
# /fs/project/PAS1307/bin/sratoolkit.2.8.2-1-ubuntu64/bin
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899426.sra is detected as single-end sequencing reads
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899427.sra is detected as single-end sequencing reads
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899438.sra is detected as single-end sequencing reads
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899437.sra is detected as single-end sequencing reads
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899421.sra is detected as single-end sequencing reads
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899428.sra is detected as single-end sequencing reads
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899434.sra is detected as single-end sequencing reads
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899430.sra is detected as single-end sequencing reads
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899433.sra is detected as single-end sequencing reads
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899425.sra is detected as single-end sequencing reads
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899422.sra is detected as single-end sequencing reads
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899435.sra is detected as single-end sequencing reads
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899436.sra is detected as single-end sequencing reads
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899432.sra is detected as single-end sequencing reads
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899431.sra is detected as single-end sequencing reads
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899423.sra is detected as single-end sequencing reads
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899424.sra is detected as single-end sequencing reads
# /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899429.sra is detected as single-end sequencing reads
# Read 17183069 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899427.sra
# Written 17183069 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899427.sra
# Read 17513754 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899428.sra
# Written 17513754 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899428.sra
# Read 17899859 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899435.sra
# Written 17899859 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899435.sra
# Read 18934244 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899430.sra
# Written 18934244 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899430.sra
# Read 17979693 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899421.sra
# Written 17979693 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899421.sra
# Read 18211995 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899432.sra
# Written 18211995 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899432.sra
# Read 18176427 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899436.sra
# Written 18176427 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899436.sra
# Read 18421390 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899434.sra
# Written 18421390 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899434.sra
# Read 18424646 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899423.sra
# Written 18424646 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899423.sra
# Read 18655823 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899437.sra
# Written 18655823 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899437.sra
# Read 18487849 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899424.sra
# Written 18487849 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899424.sra
# Read 19410496 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899426.sra
# Written 19410496 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899426.sra
# Read 18794828 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899422.sra
# Written 18794828 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899422.sra
# Read 19419534 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899431.sra
# Written 19419534 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899431.sra
# Read 19286135 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899429.sra
# Written 19286135 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899429.sra
# Read 19836280 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899433.sra
# Written 19836280 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899433.sra
# Read 20649441 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899425.sra
# Written 20649441 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899425.sra
# Read 21276620 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899438.sra
# Written 21276620 spots for /users/PAS1307/osu8805/rnaseq_2/data/sra/ERR899438.sra

# %%
old_cmd='''
#Activate the environment where cutadapt is installed.
source activate tophat
module load fastqc

#Quality filtering and adapter trimming
PHRED="20"

for basename in $(ls fastqs | cut -f1 -d '.'); do
    fq1=".fastq.gz"
    fq1=$FASTQS/$basename$fq1
    $TGBINDIR/trim_galore \
        -q $PHRED \
        -o $TFASTQS \
        $fq1
done

for basename in $(ls paired_fastqs | cut -f1 -d '_' | sort | uniq); do
    fq1="_1.fastq.gz"
    fq2="_2.fastq.gz"
    fq1=$PFASTQS/$basename$fq1
    fq2=$PFASTQS/$basename$fq2
    fqs="$fq1 $fq2"
    $TGBINDIR/trim_galore \
        -q $PHRED \
        --paired \
        -o $TPFASTQS/ \
        $fqs
done
'''

cmds = []
fastq_files = glob.glob(os.environ['FASTQS']+"/*.fastq.gz") 

for fastq_file in fastq_files:
    cmds.append("source activate rnaseq && $TGBINDIR/trim_galore -q 20 -o trimmed_fastqs "+fastq_file)
print(cmds)
    

pool = Pool(processes=MAXCORES)
results = pool.map_async(run_cmd, cmds)
pool.close()
pool.join()
pool.terminate()
# Out:
# fastqs
# ['source activate rnaseq && $TGBINDIR/trim_galore -q 20 -o trimmed_fastqs fastqs/ERR899426.fastq.gz', 'source activate rnaseq && $TGBINDIR/trim_galore -q 20 -o trimmed_fastqs fastqs/ERR899430.fastq.gz', 'source activate rnaseq && $TGBINDIR/trim_galore -q 20 -o trimmed_fastqs fastqs/ERR899435.fastq.gz', 'source activate rnaseq && $TGBINDIR/trim_galore -q 20 -o trimmed_fastqs fastqs/ERR899431.fastq.gz', 'source activate rnaseq && $TGBINDIR/trim_galore -q 20 -o trimmed_fastqs fastqs/ERR899428.fastq.gz', 'source activate rnaseq && $TGBINDIR/trim_galore -q 20 -o trimmed_fastqs fastqs/ERR899436.fastq.gz', 'source activate rnaseq && $TGBINDIR/trim_galore -q 20 -o trimmed_fastqs fastqs/ERR899425.fastq.gz', 'source activate rnaseq && $TGBINDIR/trim_galore -q 20 -o trimmed_fastqs fastqs/ERR899427.fastq.gz', 'source activate rnaseq && $TGBINDIR/trim_galore -q 20 -o trimmed_fastqs fastqs/ERR899433.fastq.gz', 'source activate rnaseq && $TGBINDIR/trim_galore -q 20 -o trimmed_fastqs fastqs/ERR899438.fastq.gz', 'source activate rnaseq && $TGBINDIR/trim_galore -q 20 -o trimmed_fastqs fastqs/ERR899437.fastq.gz', 'source activate rnaseq && $TGBINDIR/trim_galore -q 20 -o trimmed_fastqs fastqs/ERR899422.fastq.gz', 'source activate rnaseq && $TGBINDIR/trim_galore -q 20 -o trimmed_fastqs fastqs/ERR899432.fastq.gz', 'source activate rnaseq && $TGBINDIR/trim_galore -q 20 -o trimmed_fastqs fastqs/ERR899434.fastq.gz', 'source activate rnaseq && $TGBINDIR/trim_galore -q 20 -o trimmed_fastqs fastqs/ERR899421.fastq.gz', 'source activate rnaseq && $TGBINDIR/trim_galore -q 20 -o trimmed_fastqs fastqs/ERR899423.fastq.gz', 'source activate rnaseq && $TGBINDIR/trim_galore -q 20 -o trimmed_fastqs fastqs/ERR899424.fastq.gz', 'source activate rnaseq && $TGBINDIR/trim_galore -q 20 -o trimmed_fastqs fastqs/ERR899429.fastq.gz']
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# No quality encoding type selected. Assuming that the data provided uses Sanger encoded Phred scores (default)
#
# Path to Cutadapt set as: 'cutadapt' (default)
# Path to Cutadapt set as: 'cutadapt' (default)
# Path to Cutadapt set as: 'cutadapt' (default)
# Path to Cutadapt set as: 'cutadapt' (default)
# Path to Cutadapt set as: 'cutadapt' (default)
# Path to Cutadapt set as: 'cutadapt' (default)
# Path to Cutadapt set as: 'cutadapt' (default)
# Path to Cutadapt set as: 'cutadapt' (default)
# Path to Cutadapt set as: 'cutadapt' (default)
# Path to Cutadapt set as: 'cutadapt' (default)
# Path to Cutadapt set as: 'cutadapt' (default)
# Path to Cutadapt set as: 'cutadapt' (default)
# Path to Cutadapt set as: 'cutadapt' (default)
# Path to Cutadapt set as: 'cutadapt' (default)
# Path to Cutadapt set as: 'cutadapt' (default)
# Path to Cutadapt set as: 'cutadapt' (default)
# Path to Cutadapt set as: 'cutadapt' (default)
# Path to Cutadapt set as: 'cutadapt' (default)
# 1.15
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# 1.15
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# 1.15
# 1.15
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# 1.15
# 1.15
# 1.15
# 1.15
# 1.15
# 1.15
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# 1.15
# 1.15
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# 1.15
# 1.15
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# 1.15
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# 1.15
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# 1.15
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# 1.15
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
# Cutadapt seems to be working fine (tested command 'cutadapt --version')
#
#
# AUTO-DETECTING ADAPTER TYPE
# ===========================
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> fastqs/ERR899429.fastq.gz <<)
#
#
#
# AUTO-DETECTING ADAPTER TYPE
# ===========================
#
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> fastqs/ERR899425.fastq.gz <<)
#
#
# AUTO-DETECTING ADAPTER TYPE
# ===========================
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> fastqs/ERR899431.fastq.gz <<)
#
#
#
# AUTO-DETECTING ADAPTER TYPE
# ===========================
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> fastqs/ERR899421.fastq.gz <<)
#
#
#
# AUTO-DETECTING ADAPTER TYPE
# ===========================
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> fastqs/ERR899423.fastq.gz <<)
#
#
#
# AUTO-DETECTING ADAPTER TYPE
# ===========================
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> fastqs/ERR899430.fastq.gz <<)
#
#
#
# AUTO-DETECTING ADAPTER TYPE
# ===========================
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> fastqs/ERR899438.fastq.gz <<)
#
#
#
# AUTO-DETECTING ADAPTER TYPE
# ===========================
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> fastqs/ERR899426.fastq.gz <<)
#
#
#
#
#
# AUTO-DETECTING ADAPTER TYPE
# AUTO-DETECTING ADAPTER TYPE
# ===========================
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> fastqs/ERR899428.fastq.gz <<)
# ===========================
#
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> fastqs/ERR899427.fastq.gz <<)
#
#
#
# AUTO-DETECTING ADAPTER TYPE
# ===========================
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> fastqs/ERR899433.fastq.gz <<)
#
#
#
# AUTO-DETECTING ADAPTER TYPE
# ===========================
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> fastqs/ERR899437.fastq.gz <<)
#
#
#
#
#
# AUTO-DETECTING ADAPTER TYPE
#
#
# ===========================
# AUTO-DETECTING ADAPTER TYPE
# AUTO-DETECTING ADAPTER TYPE
# ===========================
# ===========================
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> fastqs/ERR899422.fastq.gz <<)
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> fastqs/ERR899435.fastq.gz <<)
#
#
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> fastqs/ERR899434.fastq.gz <<)
#
#
#
#
# AUTO-DETECTING ADAPTER TYPE
#
# ===========================
# AUTO-DETECTING ADAPTER TYPE
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> fastqs/ERR899436.fastq.gz <<)
# ===========================
#
#
# AUTO-DETECTING ADAPTER TYPE
#
# ===========================
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> fastqs/ERR899424.fastq.gz <<)
# Attempting to auto-detect adapter type from the first 1 million sequences of the first file (>> fastqs/ERR899432.fastq.gz <<)
#
#
# Found perfect matches for the following adapter sequences:
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Illumina	11195	AGATCGGAAGAGC	1000000	1.12
# Nextera	36	CTGTCTCTTATA	1000000	0.00
# smallRNA	27	TGGAATTCTCGG	1000000	0.00
# Using Illumina adapter for trimming (count: 11195). Second best hit was Nextera (count: 36)
#
# Found perfect matches for the following adapter sequences:
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Illumina	11454	AGATCGGAAGAGC	1000000	1.15
# Writing report to 'trimmed_fastqs/ERR899429.fastq.gz_trimming_report.txt'
# smallRNA	16	TGGAATTCTCGG	1000000	0.00
#
# Nextera	14	CTGTCTCTTATA	1000000	0.00
# SUMMARISING RUN PARAMETERS
# Using Illumina adapter for trimming (count: 11454). Second best hit was smallRNA (count: 16)
# ==========================
#
# Input filename: fastqs/ERR899429.fastq.gz
# Writing report to 'trimmed_fastqs/ERR899426.fastq.gz_trimming_report.txt'
#
# SUMMARISING RUN PARAMETERS
# ==========================
# Input filename: fastqs/ERR899426.fastq.gz
# Trimming mode: single-end
# Trim Galore version: 0.4.5_dev
# Found perfect matches for the following adapter sequences:
# Cutadapt version: 1.15
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Quality Phred score cutoff: 20
# Trimming mode: single-end
# Trim Galore version: 0.4.5_dev
# Quality encoding type selected: ASCII+33
# Found perfect matches for the following adapter sequences:
# Illumina	5849	AGATCGGAAGAGC	1000000	0.58
# Nextera	32	CTGTCTCTTATA	1000000	0.00
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# smallRNA	26	TGGAATTCTCGG	1000000	0.00
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; auto-detected)
# Using Illumina adapter for trimming (count: 5849). Second best hit was Nextera (count: 32)
#
# Maximum trimming error rate: 0.1 (default)
# Minimum required adapter overlap (stringency): 1 bp
# Writing report to 'trimmed_fastqs/ERR899433.fastq.gz_trimming_report.txt'
#
# SUMMARISING RUN PARAMETERS
# ==========================
# Input filename: fastqs/ERR899433.fastq.gz
# Minimum required sequence length before a sequence gets removed: 20 bp
# Trimming mode: single-end
# Output file(s) will be GZIP compressed
# Trim Galore version: 0.4.5_dev
#
# Cutadapt version: 1.15
# Quality Phred score cutoff: 20
# Quality encoding type selected: ASCII+33
# Cutadapt version: 1.15
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; auto-detected)
# Quality Phred score cutoff: 20
# Quality encoding type selected: ASCII+33
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; auto-detected)
# Maximum trimming error rate: 0.1 (default)
# Maximum trimming error rate: 0.1 (default)
# Minimum required adapter overlap (stringency): 1 bp
# Minimum required adapter overlap (stringency): 1 bp
# Minimum required sequence length before a sequence gets removed: 20 bp
# Minimum required sequence length before a sequence gets removed: 20 bp
# Output file(s) will be GZIP compressed
#
# Output file(s) will be GZIP compressed
# Illumina	5460	AGATCGGAAGAGC	1000000	0.55
# smallRNA	19	TGGAATTCTCGG	1000000	0.00
# Nextera	12	CTGTCTCTTATA	1000000	0.00
# Using Illumina adapter for trimming (count: 5460). Second best hit was smallRNA (count: 19)
#
# Found perfect matches for the following adapter sequences:
#
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Writing report to 'trimmed_fastqs/ERR899434.fastq.gz_trimming_report.txt'
# Illumina	5633	AGATCGGAAGAGC	1000000	0.56
#
# smallRNA	9	TGGAATTCTCGG	1000000	0.00
# SUMMARISING RUN PARAMETERS
# Nextera	8	CTGTCTCTTATA	1000000	0.00
# ==========================
# Using Illumina adapter for trimming (count: 5633). Second best hit was smallRNA (count: 9)
# Input filename: fastqs/ERR899434.fastq.gz
#
# Trimming mode: single-end
# Writing report to 'trimmed_fastqs/ERR899430.fastq.gz_trimming_report.txt'
# Trim Galore version: 0.4.5_dev
#
# Cutadapt version: 1.15
# SUMMARISING RUN PARAMETERS
# Quality Phred score cutoff: 20
# Quality encoding type selected: ASCII+33
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; auto-detected)
# Maximum trimming error rate: 0.1 (default)
# Minimum required adapter overlap (stringency): 1 bp
# Minimum required sequence length before a sequence gets removed: 20 bp
# Output file(s) will be GZIP compressed
# Found perfect matches for the following adapter sequences:
#
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# ==========================
# Illumina	5684	AGATCGGAAGAGC	1000000	0.57
# Input filename: fastqs/ERR899430.fastq.gz
# Trimming mode: single-end
# Nextera	16	CTGTCTCTTATA	1000000	0.00
# Trim Galore version: 0.4.5_dev
# Cutadapt version: 1.15
# Quality Phred score cutoff: 20
# Quality encoding type selected: ASCII+33
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; auto-detected)
# smallRNA	12	TGGAATTCTCGG	1000000	0.00
# Maximum trimming error rate: 0.1 (default)
# Using Illumina adapter for trimming (count: 5684). Second best hit was Nextera (count: 16)
# Minimum required adapter overlap (stringency): 1 bp
#
# Minimum required sequence length before a sequence gets removed: 20 bp
# Writing report to 'trimmed_fastqs/ERR899428.fastq.gz_trimming_report.txt'
# Output file(s) will be GZIP compressed
#
#
# SUMMARISING RUN PARAMETERS
# ==========================
# Input filename: fastqs/ERR899428.fastq.gz
# Trimming mode: single-end
# Trim Galore version: 0.4.5_dev
# Cutadapt version: 1.15
# Quality Phred score cutoff: 20
# Quality encoding type selected: ASCII+33
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; auto-detected)
# Maximum trimming error rate: 0.1 (default)
# Minimum required adapter overlap (stringency): 1 bp
# Minimum required sequence length before a sequence gets removed: 20 bp
# Output file(s) will be GZIP compressed
# Found perfect matches for the following adapter sequences:
# Adapter type	Count	Sequence	Sequences analysed	Percentage
#
# Illumina	7172	AGATCGGAAGAGC	1000000	0.72
# Nextera	35	CTGTCTCTTATA	1000000	0.00
# smallRNA	21	TGGAATTCTCGG	1000000	0.00
# Using Illumina adapter for trimming (count: 7172). Second best hit was Nextera (count: 35)
#
# Writing report to 'trimmed_fastqs/ERR899431.fastq.gz_trimming_report.txt'
#
# SUMMARISING RUN PARAMETERS
# Found perfect matches for the following adapter sequences:
# ==========================
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Input filename: fastqs/ERR899431.fastq.gz
# Trimming mode: single-end
# Trim Galore version: 0.4.5_dev
# Cutadapt version: 1.15
# Quality Phred score cutoff: 20
# Illumina	6043	AGATCGGAAGAGC	1000000	0.60
# Nextera	20	CTGTCTCTTATA	1000000	0.00
# Quality encoding type selected: ASCII+33
# smallRNA	8	TGGAATTCTCGG	1000000	0.00
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; auto-detected)
# Using Illumina adapter for trimming (count: 6043). Second best hit was Nextera (count: 20)
# Maximum trimming error rate: 0.1 (default)
#
# Minimum required adapter overlap (stringency): 1 bp
# Writing report to 'trimmed_fastqs/ERR899435.fastq.gz_trimming_report.txt'
# Minimum required sequence length before a sequence gets removed: 20 bp
#
# Output file(s) will be GZIP compressed
# SUMMARISING RUN PARAMETERS
#
# ==========================
# Input filename: fastqs/ERR899435.fastq.gz
# Trimming mode: single-end
# Trim Galore version: 0.4.5_dev
# Cutadapt version: 1.15
# Quality Phred score cutoff: 20
# Quality encoding type selected: ASCII+33
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; auto-detected)
# Maximum trimming error rate: 0.1 (default)
# Minimum required adapter overlap (stringency): 1 bp
# Found perfect matches for the following adapter sequences:
# Minimum required sequence length before a sequence gets removed: 20 bp
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Output file(s) will be GZIP compressed
# Illumina	7575	AGATCGGAAGAGC	1000000	0.76
#
# smallRNA	14	TGGAATTCTCGG	1000000	0.00
# Nextera	9	CTGTCTCTTATA	1000000	0.00
# Using Illumina adapter for trimming (count: 7575). Second best hit was smallRNA (count: 14)
#
# Writing report to 'trimmed_fastqs/ERR899422.fastq.gz_trimming_report.txt'
#
# SUMMARISING RUN PARAMETERS
# ==========================
# Input filename: fastqs/ERR899422.fastq.gz
# Trimming mode: single-end
# Trim Galore version: 0.4.5_dev
# Cutadapt version: 1.15
# Quality Phred score cutoff: 20
# Quality encoding type selected: ASCII+33
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; auto-detected)
# Maximum trimming error rate: 0.1 (default)
# Minimum required adapter overlap (stringency): 1 bp
# Minimum required sequence length before a sequence gets removed: 20 bp
# Output file(s) will be GZIP compressed
#
# Found perfect matches for the following adapter sequences:
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Illumina	7784	AGATCGGAAGAGC	1000000	0.78
# smallRNA	9	TGGAATTCTCGG	1000000	0.00
# Nextera	6	CTGTCTCTTATA	1000000	0.00
# Using Illumina adapter for trimming (count: 7784). Second best hit was smallRNA (count: 9)
#
# Writing report to 'trimmed_fastqs/ERR899425.fastq.gz_trimming_report.txt'
#
# SUMMARISING RUN PARAMETERS
# ==========================
# Input filename: fastqs/ERR899425.fastq.gz
# Trimming mode: single-end
# Trim Galore version: 0.4.5_dev
# Cutadapt version: 1.15
# Quality Phred score cutoff: 20
# Quality encoding type selected: ASCII+33
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; auto-detected)
# Maximum trimming error rate: 0.1 (default)
# Minimum required adapter overlap (stringency): 1 bp
# Minimum required sequence length before a sequence gets removed: 20 bp
# Output file(s) will be GZIP compressed
#
# Found perfect matches for the following adapter sequences:
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Illumina	8060	AGATCGGAAGAGC	1000000	0.81
# Nextera	19	CTGTCTCTTATA	1000000	0.00
# smallRNA	16	TGGAATTCTCGG	1000000	0.00
# Using Illumina adapter for trimming (count: 8060). Second best hit was Nextera (count: 19)
#
# Writing report to 'trimmed_fastqs/ERR899421.fastq.gz_trimming_report.txt'
#
# SUMMARISING RUN PARAMETERS
# ==========================
# Input filename: fastqs/ERR899421.fastq.gz
# Trimming mode: single-end
# Trim Galore version: 0.4.5_dev
# Cutadapt version: 1.15
# Quality Phred score cutoff: 20
# Maximum trimming error rate: 0.1 (default)
# Quality encoding type selected: ASCII+33
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; auto-detected)
# Minimum required adapter overlap (stringency): 1 bp
# Minimum required sequence length before a sequence gets removed: 20 bp
# Output file(s) will be GZIP compressed
#
# Found perfect matches for the following adapter sequences:
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Illumina	5567	AGATCGGAAGAGC	1000000	0.56
# Nextera	39	CTGTCTCTTATA	1000000	0.00
# smallRNA	22	TGGAATTCTCGG	1000000	0.00
# Using Illumina adapter for trimming (count: 5567). Second best hit was Nextera (count: 39)
#
# Writing report to 'trimmed_fastqs/ERR899432.fastq.gz_trimming_report.txt'
#
# SUMMARISING RUN PARAMETERS
# ==========================
# Input filename: fastqs/ERR899432.fastq.gz
# Trimming mode: single-end
# Trim Galore version: 0.4.5_dev
# Cutadapt version: 1.15
# Quality Phred score cutoff: 20
# Quality encoding type selected: ASCII+33
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; auto-detected)
# Maximum trimming error rate: 0.1 (default)
# Minimum required adapter overlap (stringency): 1 bp
# Minimum required sequence length before a sequence gets removed: 20 bp
# Output file(s) will be GZIP compressed
#
# Found perfect matches for the following adapter sequences:
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Illumina	7627	AGATCGGAAGAGC	1000000	0.76
# smallRNA	17	TGGAATTCTCGG	1000000	0.00
# Nextera	13	CTGTCTCTTATA	1000000	0.00
# Using Illumina adapter for trimming (count: 7627). Second best hit was smallRNA (count: 17)
#
# Writing report to 'trimmed_fastqs/ERR899423.fastq.gz_trimming_report.txt'
# Found perfect matches for the following adapter sequences:
#
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# SUMMARISING RUN PARAMETERS
# Illumina	5778	AGATCGGAAGAGC	1000000	0.58
# ==========================
# Nextera	31	CTGTCTCTTATA	1000000	0.00
# Input filename: fastqs/ERR899423.fastq.gz
# smallRNA	29	TGGAATTCTCGG	1000000	0.00
# Trimming mode: single-end
# Using Illumina adapter for trimming (count: 5778). Second best hit was Nextera (count: 31)
# Trim Galore version: 0.4.5_dev
#
# Cutadapt version: 1.15
# Writing report to 'trimmed_fastqs/ERR899427.fastq.gz_trimming_report.txt'
#
# Quality Phred score cutoff: 20
# SUMMARISING RUN PARAMETERS
# Quality encoding type selected: ASCII+33
# ==========================
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; auto-detected)
# Input filename: fastqs/ERR899427.fastq.gz
# Maximum trimming error rate: 0.1 (default)
# Trimming mode: single-end
# Minimum required adapter overlap (stringency): 1 bp
# Trim Galore version: 0.4.5_dev
# Minimum required sequence length before a sequence gets removed: 20 bp
# Cutadapt version: 1.15
# Output file(s) will be GZIP compressed
# Quality Phred score cutoff: 20
#
# Quality encoding type selected: ASCII+33
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; auto-detected)
# Maximum trimming error rate: 0.1 (default)
# Minimum required adapter overlap (stringency): 1 bp
# Minimum required sequence length before a sequence gets removed: 20 bp
# Output file(s) will be GZIP compressed
#
# Found perfect matches for the following adapter sequences:
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Illumina	6028	AGATCGGAAGAGC	1000000	0.60
# Nextera	13	CTGTCTCTTATA	1000000	0.00
# smallRNA	9	TGGAATTCTCGG	1000000	0.00
# Using Illumina adapter for trimming (count: 6028). Second best hit was Nextera (count: 13)
#
# Writing report to 'trimmed_fastqs/ERR899424.fastq.gz_trimming_report.txt'
#
# SUMMARISING RUN PARAMETERS
# ==========================
# Input filename: fastqs/ERR899424.fastq.gz
# Trimming mode: single-end
# Trim Galore version: 0.4.5_dev
# Cutadapt version: 1.15
# Quality Phred score cutoff: 20
# Found perfect matches for the following adapter sequences:
# Quality encoding type selected: ASCII+33
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; auto-detected)
# Maximum trimming error rate: 0.1 (default)
# Illumina	6287	AGATCGGAAGAGC	1000000	0.63
# Minimum required adapter overlap (stringency): 1 bp
# smallRNA	16	TGGAATTCTCGG	1000000	0.00
# Found perfect matches for the following adapter sequences:
# Minimum required sequence length before a sequence gets removed: 20 bp
# Nextera	15	CTGTCTCTTATA	1000000	0.00
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Output file(s) will be GZIP compressed
# Using Illumina adapter for trimming (count: 6287). Second best hit was smallRNA (count: 16)
# Illumina	7006	AGATCGGAAGAGC	1000000	0.70
#
#
# Nextera	27	CTGTCTCTTATA	1000000	0.00
# Writing report to 'trimmed_fastqs/ERR899436.fastq.gz_trimming_report.txt'
# smallRNA	20	TGGAATTCTCGG	1000000	0.00
#
# Using Illumina adapter for trimming (count: 7006). Second best hit was Nextera (count: 27)
# SUMMARISING RUN PARAMETERS
#
# ==========================
# Writing report to 'trimmed_fastqs/ERR899438.fastq.gz_trimming_report.txt'
# Input filename: fastqs/ERR899436.fastq.gz
#
# Trimming mode: single-end
# SUMMARISING RUN PARAMETERS
# Trim Galore version: 0.4.5_dev
# ==========================
# Cutadapt version: 1.15
# Input filename: fastqs/ERR899438.fastq.gz
# Quality Phred score cutoff: 20
# Trimming mode: single-end
# Quality encoding type selected: ASCII+33
# Trim Galore version: 0.4.5_dev
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; auto-detected)
# Cutadapt version: 1.15
# Quality Phred score cutoff: 20
# Maximum trimming error rate: 0.1 (default)
# Quality encoding type selected: ASCII+33
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; auto-detected)
# Minimum required adapter overlap (stringency): 1 bp
# Maximum trimming error rate: 0.1 (default)
# Minimum required adapter overlap (stringency): 1 bp
# Minimum required sequence length before a sequence gets removed: 20 bp
# Minimum required sequence length before a sequence gets removed: 20 bp
# Output file(s) will be GZIP compressed
# Output file(s) will be GZIP compressed
#
#
# Found perfect matches for the following adapter sequences:
# Adapter type	Count	Sequence	Sequences analysed	Percentage
# Illumina	9320	AGATCGGAAGAGC	1000000	0.93
# smallRNA	18	TGGAATTCTCGG	1000000	0.00
# Nextera	17	CTGTCTCTTATA	1000000	0.00
# Using Illumina adapter for trimming (count: 9320). Second best hit was smallRNA (count: 18)
#
# Writing report to 'trimmed_fastqs/ERR899437.fastq.gz_trimming_report.txt'
#
# SUMMARISING RUN PARAMETERS
# ==========================
# Input filename: fastqs/ERR899437.fastq.gz
# Trimming mode: single-end
# Trim Galore version: 0.4.5_dev
# Cutadapt version: 1.15
# Quality Phred score cutoff: 20
# Quality encoding type selected: ASCII+33
# Adapter sequence: 'AGATCGGAAGAGC' (Illumina TruSeq, Sanger iPCR; auto-detected)
# Maximum trimming error rate: 0.1 (default)
# Minimum required adapter overlap (stringency): 1 bp
# Minimum required sequence length before a sequence gets removed: 20 bp
# Output file(s) will be GZIP compressed
#
# Writing final adapter and quality trimmed output to ERR899429_trimmed.fq.gz
#
#
# >>> Now performing quality (cutoff 20) and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file fastqs/ERR899429.fastq.gz <<<
# Writing final adapter and quality trimmed output to ERR899426_trimmed.fq.gz
#
#
# >>> Now performing quality (cutoff 20) and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file fastqs/ERR899426.fastq.gz <<<
# Writing final adapter and quality trimmed output to ERR899433_trimmed.fq.gz
#
#
# >>> Now performing quality (cutoff 20) and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file fastqs/ERR899433.fastq.gz <<<
# Writing final adapter and quality trimmed output to ERR899434_trimmed.fq.gz
#
#
# >>> Now performing quality (cutoff 20) and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file fastqs/ERR899434.fastq.gz <<<
# Writing final adapter and quality trimmed output to ERR899430_trimmed.fq.gz
#
#
# >>> Now performing quality (cutoff 20) and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file fastqs/ERR899430.fastq.gz <<<
# Writing final adapter and quality trimmed output to ERR899428_trimmed.fq.gz
#
#
# >>> Now performing quality (cutoff 20) and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file fastqs/ERR899428.fastq.gz <<<
# Writing final adapter and quality trimmed output to ERR899431_trimmed.fq.gz
#
#
# >>> Now performing quality (cutoff 20) and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file fastqs/ERR899431.fastq.gz <<<
# Writing final adapter and quality trimmed output to ERR899435_trimmed.fq.gz
#
#
# >>> Now performing quality (cutoff 20) and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file fastqs/ERR899435.fastq.gz <<<
# Writing final adapter and quality trimmed output to ERR899422_trimmed.fq.gz
#
#
# >>> Now performing quality (cutoff 20) and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file fastqs/ERR899422.fastq.gz <<<
# Writing final adapter and quality trimmed output to ERR899425_trimmed.fq.gz
#
#
# >>> Now performing quality (cutoff 20) and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file fastqs/ERR899425.fastq.gz <<<
# Writing final adapter and quality trimmed output to ERR899421_trimmed.fq.gz
#
#
# >>> Now performing quality (cutoff 20) and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file fastqs/ERR899421.fastq.gz <<<
# Writing final adapter and quality trimmed output to ERR899432_trimmed.fq.gz
#
#
# >>> Now performing quality (cutoff 20) and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file fastqs/ERR899432.fastq.gz <<<
# Writing final adapter and quality trimmed output to ERR899423_trimmed.fq.gz
#
#
# >>> Now performing quality (cutoff 20) and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file fastqs/ERR899423.fastq.gz <<<
# Writing final adapter and quality trimmed output to ERR899427_trimmed.fq.gz
#
#
# >>> Now performing quality (cutoff 20) and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file fastqs/ERR899427.fastq.gz <<<
# Writing final adapter and quality trimmed output to ERR899424_trimmed.fq.gz
#
#
# >>> Now performing quality (cutoff 20) and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file fastqs/ERR899424.fastq.gz <<<
# Writing final adapter and quality trimmed output to ERR899436_trimmed.fq.gz
#
#
# >>> Now performing quality (cutoff 20) and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file fastqs/ERR899436.fastq.gz <<<
# Writing final adapter and quality trimmed output to ERR899437_trimmed.fq.gz
# Writing final adapter and quality trimmed output to ERR899438_trimmed.fq.gz
#
#
#
#
# >>> Now performing quality (cutoff 20) and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file fastqs/ERR899437.fastq.gz <<<
# >>> Now performing quality (cutoff 20) and adapter trimming in a single pass for the adapter sequence: 'AGATCGGAAGAGC' from file fastqs/ERR899438.fastq.gz <<<
# 10000000 sequences processed
# 10000000 sequences processed
# 10000000 sequences processed
# 10000000 sequences processed
# 10000000 sequences processed
# 10000000 sequences processed
# 10000000 sequences processed
# 10000000 sequences processed
# 10000000 sequences processed
# 10000000 sequences processed
# 10000000 sequences processed
# 10000000 sequences processed
# 10000000 sequences processed
# 10000000 sequences processed
# 10000000 sequences processed
# 10000000 sequences processed
# 10000000 sequences processed
# 10000000 sequences processed
# This is cutadapt 1.15 with Python 3.6.4
# Command line parameters: -f fastq -e 0.1 -q 20 -O 1 -a AGATCGGAAGAGC fastqs/ERR899427.fastq.gz
# Running on 1 core
# Trimming 1 adapter with at most 10.0% errors in single-end mode ...
# Finished in 606.45 s (35 us/read; 1.70 M reads/minute).
#
# === Summary ===
#
# Total reads processed:              17,183,069
# Reads with adapters:                 5,715,645 (33.3%)
# Reads written (passing filters):    17,183,069 (100.0%)
#
# Total basepairs processed: 1,718,306,900 bp
# Quality-trimmed:              18,179,078 bp (1.1%)
# Total written (filtered):  1,689,055,644 bp (98.3%)
#
# === Adapter 1 ===
#
# Sequence: AGATCGGAAGAGC; Type: regular 3'; Length: 13; Trimmed: 5715645 times.
#
# No. of allowed errors:
# 0-9 bp: 0; 10-13 bp: 1
#
# Bases preceding removed adapters:
# A: 28.5%
# C: 33.9%
# G: 19.3%
# T: 18.2%
# none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 1	3833726	4295767.2	0	3833726
# 2	1214028	1073941.8	0	1214028
# 3	318026	268485.5	0	318026
# 4	89957	67121.4	0	89957
# 5	39843	16780.3	0	39843
# 6	22968	4195.1	0	22968
# 7	19607	1048.8	0	19607
# 8	17274	262.2	0	17274
# 9	15642	65.5	0	15387 255
# 10	14580	16.4	1	13681 899
# 11	12800	4.1	1	12166 634
# 12	11858	1.0	1	11372 486
# 13	10587	0.3	1	10126 461
# 14	9903	0.3	1	9481 422
# 15	9084	0.3	1	8685 399
# 16	8249	0.3	1	7884 365
# 17	7503	0.3	1	7167 336
# 18	6685	0.3	1	6423 262
# 19	5491	0.3	1	5258 233
# 20	4942	0.3	1	4710 232
# 21	4365	0.3	1	4185 180
# 22	3934	0.3	1	3739 195
# 23	3530	0.3	1	3374 156
# 24	3289	0.3	1	3128 161
# 25	2962	0.3	1	2833 129
# 26	2685	0.3	1	2579 106
# 27	2445	0.3	1	2328 117
# 28	2111	0.3	1	2004 107
# 29	1813	0.3	1	1722 91
# 30	1667	0.3	1	1573 94
# 31	1315	0.3	1	1261 54
# 32	1202	0.3	1	1148 54
# 33	1062	0.3	1	1000 62
# 34	961	0.3	1	905 56
# 35	967	0.3	1	914 53
# 36	764	0.3	1	718 46
# 37	727	0.3	1	682 45
# 38	628	0.3	1	596 32
# 39	533	0.3	1	505 28
# 40	459	0.3	1	417 42
# 41	413	0.3	1	384 29
# 42	338	0.3	1	317 21
# 43	326	0.3	1	313 13
# 44	269	0.3	1	242 27
# 45	257	0.3	1	234 23
# 46	243	0.3	1	219 24
# 47	261	0.3	1	225 36
# 48	227	0.3	1	204 23
# 49	168	0.3	1	153 15
# 50	149	0.3	1	125 24
# 51	123	0.3	1	115 8
# 52	92	0.3	1	76 16
# 53	103	0.3	1	86 17
# 54	100	0.3	1	87 13
# 55	74	0.3	1	67 7
# 56	90	0.3	1	49 41
# 57	72	0.3	1	50 22
# 58	95	0.3	1	55 40
# 59	56	0.3	1	29 27
# 60	45	0.3	1	27 18
# 61	47	0.3	1	28 19
# 62	40	0.3	1	19 21
# 63	45	0.3	1	21 24
# 64	53	0.3	1	19 34
# 65	67	0.3	1	27 40
# 66	61	0.3	1	27 34
# 67	44	0.3	1	15 29
# 68	58	0.3	1	16 42
# 69	81	0.3	1	10 71
# 70	128	0.3	1	23 105
# 71	441	0.3	1	27 414
# 72	249	0.3	1	107 142
# 73	86	0.3	1	36 50
# 74	108	0.3	1	23 85
# 75	13	0.3	1	2 11
# 76	17	0.3	1	3 14
# 77	24	0.3	1	3 21
# 78	21	0.3	1	2 19
# 79	18	0.3	1	2 16
# 80	11	0.3	1	1 10
# 81	19	0.3	1	1 18
# 82	29	0.3	1	0 29
# 83	40	0.3	1	0 40
# 84	9	0.3	1	1 8
# 85	19	0.3	1	0 19
# 86	20	0.3	1	0 20
# 87	16	0.3	1	0 16
# 88	19	0.3	1	1 18
# 89	16	0.3	1	0 16
# 90	12	0.3	1	0 12
# 91	18	0.3	1	0 18
# 92	5	0.3	1	0 5
# 93	6	0.3	1	0 6
# 94	11	0.3	1	0 11
# 95	13	0.3	1	1 12
# 96	22	0.3	1	0 22
# 97	7	0.3	1	1 6
# 98	5	0.3	1	0 5
# 99	9	0.3	1	0 9
# 100	65	0.3	1	1 64
#
#
# RUN STATISTICS FOR INPUT FILE: fastqs/ERR899427.fastq.gz
# =============================================
# 17183069 sequences processed in total
# Sequences removed because they became shorter than the length cutoff of 20 bp:	4146 (0.0%)
#
# This is cutadapt 1.15 with Python 3.6.4
# Command line parameters: -f fastq -e 0.1 -q 20 -O 1 -a AGATCGGAAGAGC fastqs/ERR899428.fastq.gz
# Running on 1 core
# Trimming 1 adapter with at most 10.0% errors in single-end mode ...
# Finished in 614.42 s (35 us/read; 1.71 M reads/minute).
#
# === Summary ===
#
# Total reads processed:              17,513,754
# Reads with adapters:                 5,912,940 (33.8%)
# Reads written (passing filters):    17,513,754 (100.0%)
#
# Total basepairs processed: 1,751,375,400 bp
# Quality-trimmed:              18,659,765 bp (1.1%)
# Total written (filtered):  1,721,197,884 bp (98.3%)
#
# === Adapter 1 ===
#
# Sequence: AGATCGGAAGAGC; Type: regular 3'; Length: 13; Trimmed: 5912940 times.
#
# No. of allowed errors:
# 0-9 bp: 0; 10-13 bp: 1
#
# Bases preceding removed adapters:
# A: 28.9%
# C: 33.5%
# G: 19.2%
# T: 18.4%
# none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 1	3975796	4378438.5	0	3975796
# 2	1245174	1094609.6	0	1245174
# 3	323946	273652.4	0	323946
# 4	94193	68413.1	0	94193
# 5	41397	17103.3	0	41397
# 6	23770	4275.8	0	23770
# 7	19936	1069.0	0	19936
# 8	17233	267.2	0	17233
# 9	16542	66.8	0	16318 224
# 10	15454	16.7	1	13627 1827
# 11	13559	4.2	1	12089 1470
# 12	12738	1.0	1	11527 1211
# 13	11129	0.3	1	10091 1038
# 14	10870	0.3	1	9869 1001
# 15	10015	0.3	1	9089 926
# 16	9043	0.3	1	8178 865
# 17	8121	0.3	1	7285 836
# 18	7148	0.3	1	6440 708
# 19	5871	0.3	1	5283 588
# 20	5312	0.3	1	4749 563
# 21	4516	0.3	1	4061 455
# 22	4109	0.3	1	3711 398
# 23	3823	0.3	1	3413 410
# 24	3458	0.3	1	3085 373
# 25	3275	0.3	1	2933 342
# 26	2860	0.3	1	2579 281
# 27	2578	0.3	1	2312 266
# 28	2370	0.3	1	2137 233
# 29	1942	0.3	1	1746 196
# 30	1700	0.3	1	1501 199
# 31	1406	0.3	1	1278 128
# 32	1333	0.3	1	1194 139
# 33	1090	0.3	1	978 112
# 34	1084	0.3	1	974 110
# 35	941	0.3	1	859 82
# 36	936	0.3	1	840 96
# 37	819	0.3	1	707 112
# 38	716	0.3	1	637 79
# 39	650	0.3	1	580 70
# 40	506	0.3	1	430 76
# 41	423	0.3	1	362 61
# 42	375	0.3	1	326 49
# 43	314	0.3	1	284 30
# 44	294	0.3	1	267 27
# 45	313	0.3	1	282 31
# 46	276	0.3	1	242 34
# 47	286	0.3	1	246 40
# 48	231	0.3	1	197 34
# 49	202	0.3	1	166 36
# 50	178	0.3	1	150 28
# 51	159	0.3	1	140 19
# 52	127	0.3	1	94 33
# 53	97	0.3	1	74 23
# 54	79	0.3	1	68 11
# 55	105	0.3	1	86 19
# 56	102	0.3	1	55 47
# 57	70	0.3	1	52 18
# 58	107	0.3	1	54 53
# 59	62	0.3	1	41 21
# 60	63	0.3	1	40 23
# 61	40	0.3	1	30 10
# 62	36	0.3	1	19 17
# 63	36	0.3	1	22 14
# 64	46	0.3	1	16 30
# 65	57	0.3	1	21 36
# 66	49	0.3	1	30 19
# 67	26	0.3	1	16 10
# 68	49	0.3	1	19 30
# 69	71	0.3	1	12 59
# 70	122	0.3	1	22 100
# 71	372	0.3	1	49 323
# 72	206	0.3	1	112 94
# 73	76	0.3	1	40 36
# 74	115	0.3	1	16 99
# 75	25	0.3	1	11 14
# 76	19	0.3	1	2 17
# 77	19	0.3	1	3 16
# 78	17	0.3	1	0 17
# 79	15	0.3	1	3 12
# 80	14	0.3	1	1 13
# 81	10	0.3	1	1 9
# 82	18	0.3	1	0 18
# 83	26	0.3	1	0 26
# 84	13	0.3	1	1 12
# 85	12	0.3	1	0 12
# 86	16	0.3	1	0 16
# 87	17	0.3	1	1 16
# 88	21	0.3	1	0 21
# 89	21	0.3	1	0 21
# 90	12	0.3	1	0 12
# 91	12	0.3	1	0 12
# 92	20	0.3	1	0 20
# 93	10	0.3	1	2 8
# 94	6	0.3	1	0 6
# 95	4	0.3	1	1 3
# 96	20	0.3	1	0 20
# 97	12	0.3	1	2 10
# 98	13	0.3	1	1 12
# 99	5	0.3	1	1 4
# 100	40	0.3	1	1 39
#
#
# RUN STATISTICS FOR INPUT FILE: fastqs/ERR899428.fastq.gz
# =============================================
# 17513754 sequences processed in total
# Sequences removed because they became shorter than the length cutoff of 20 bp:	3937 (0.0%)
#
# This is cutadapt 1.15 with Python 3.6.4
# Command line parameters: -f fastq -e 0.1 -q 20 -O 1 -a AGATCGGAAGAGC fastqs/ERR899435.fastq.gz
# Running on 1 core
# Trimming 1 adapter with at most 10.0% errors in single-end mode ...
# Finished in 626.45 s (35 us/read; 1.71 M reads/minute).
#
# === Summary ===
#
# Total reads processed:              17,899,859
# Reads with adapters:                 5,992,885 (33.5%)
# Reads written (passing filters):    17,899,859 (100.0%)
#
# Total basepairs processed: 1,789,985,900 bp
# Quality-trimmed:              18,555,538 bp (1.0%)
# Total written (filtered):  1,759,628,077 bp (98.3%)
#
# === Adapter 1 ===
#
# Sequence: AGATCGGAAGAGC; Type: regular 3'; Length: 13; Trimmed: 5992885 times.
#
# No. of allowed errors:
# 0-9 bp: 0; 10-13 bp: 1
#
# Bases preceding removed adapters:
# A: 28.1%
# C: 34.7%
# G: 19.4%
# T: 17.8%
# none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 1	3999291	4474964.8	0	3999291
# 2	1282222	1118741.2	0	1282222
# 3	332866	279685.3	0	332866
# 4	95522	69921.3	0	95522
# 5	42887	17480.3	0	42887
# 6	24950	4370.1	0	24950
# 7	21206	1092.5	0	21206
# 8	18488	273.1	0	18488
# 9	16994	68.3	0	16704 290
# 10	15911	17.1	1	14897 1014
# 11	13870	4.3	1	13019 851
# 12	12783	1.1	1	12181 602
# 13	11300	0.3	1	10861 439
# 14	10643	0.3	1	10200 443
# 15	9754	0.3	1	9345 409
# 16	8937	0.3	1	8523 414
# 17	8092	0.3	1	7702 390
# 18	7299	0.3	1	6942 357
# 19	6007	0.3	1	5744 263
# 20	5351	0.3	1	5084 267
# 21	4724	0.3	1	4475 249
# 22	4345	0.3	1	4148 197
# 23	3747	0.3	1	3547 200
# 24	3638	0.3	1	3474 164
# 25	3380	0.3	1	3195 185
# 26	3070	0.3	1	2934 136
# 27	2821	0.3	1	2697 124
# 28	2347	0.3	1	2241 106
# 29	2048	0.3	1	1962 86
# 30	1819	0.3	1	1704 115
# 31	1481	0.3	1	1409 72
# 32	1341	0.3	1	1286 55
# 33	1156	0.3	1	1102 54
# 34	1176	0.3	1	1102 74
# 35	1070	0.3	1	997 73
# 36	1003	0.3	1	943 60
# 37	835	0.3	1	780 55
# 38	776	0.3	1	732 44
# 39	682	0.3	1	643 39
# 40	552	0.3	1	507 45
# 41	470	0.3	1	446 24
# 42	430	0.3	1	400 30
# 43	355	0.3	1	335 20
# 44	400	0.3	1	364 36
# 45	327	0.3	1	300 27
# 46	281	0.3	1	253 28
# 47	296	0.3	1	277 19
# 48	252	0.3	1	227 25
# 49	194	0.3	1	169 25
# 50	195	0.3	1	171 24
# 51	162	0.3	1	147 15
# 52	142	0.3	1	123 19
# 53	115	0.3	1	101 14
# 54	93	0.3	1	77 16
# 55	100	0.3	1	90 10
# 56	105	0.3	1	75 30
# 57	78	0.3	1	67 11
# 58	97	0.3	1	61 36
# 59	89	0.3	1	62 27
# 60	83	0.3	1	52 31
# 61	62	0.3	1	45 17
# 62	53	0.3	1	32 21
# 63	53	0.3	1	27 26
# 64	51	0.3	1	28 23
# 65	74	0.3	1	26 48
# 66	50	0.3	1	29 21
# 67	49	0.3	1	17 32
# 68	66	0.3	1	14 52
# 69	122	0.3	1	23 99
# 70	153	0.3	1	27 126
# 71	541	0.3	1	52 489
# 72	247	0.3	1	134 113
# 73	88	0.3	1	40 48
# 74	124	0.3	1	12 112
# 75	22	0.3	1	14 8
# 76	16	0.3	1	4 12
# 77	25	0.3	1	2 23
# 78	31	0.3	1	2 29
# 79	15	0.3	1	1 14
# 80	18	0.3	1	1 17
# 81	14	0.3	1	1 13
# 82	18	0.3	1	1 17
# 83	28	0.3	1	0 28
# 84	12	0.3	1	1 11
# 85	25	0.3	1	0 25
# 86	33	0.3	1	0 33
# 87	11	0.3	1	1 10
# 88	37	0.3	1	1 36
# 89	15	0.3	1	1 14
# 90	10	0.3	1	0 10
# 91	16	0.3	1	1 15
# 92	13	0.3	1	0 13
# 93	8	0.3	1	1 7
# 94	11	0.3	1	0 11
# 95	14	0.3	1	2 12
# 96	19	0.3	1	1 18
# 97	12	0.3	1	1 11
# 98	8	0.3	1	1 7
# 99	8	0.3	1	0 8
# 100	65	0.3	1	0 65
#
# This is cutadapt 1.15 with Python 3.6.4
# Command line parameters: -f fastq -e 0.1 -q 20 -O 1 -a AGATCGGAAGAGC fastqs/ERR899421.fastq.gz
# Running on 1 core
# Trimming 1 adapter with at most 10.0% errors in single-end mode ...
# Finished in 632.70 s (35 us/read; 1.71 M reads/minute).
#
# === Summary ===
#
# Total reads processed:              17,979,693
# Reads with adapters:                 6,092,945 (33.9%)
# Reads written (passing filters):    17,979,693 (100.0%)
#
# Total basepairs processed: 1,797,969,300 bp
# Quality-trimmed:              18,790,294 bp (1.0%)
# Total written (filtered):  1,766,392,323 bp (98.2%)
#
# === Adapter 1 ===
#
# Sequence: AGATCGGAAGAGC; Type: regular 3'; Length: 13; Trimmed: 6092945 times.
#
# No. of allowed errors:
# 0-9 bp: 0; 10-13 bp: 1
#
# Bases preceding removed adapters:
# A: 28.1%
# C: 34.2%
# G: 19.8%
# T: 17.9%
# none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 1	4021207	4494923.2	0	4021207
# 2	1286435	1123730.8	0	1286435
# 3	339826	280932.7	0	339826
# 4	99285	70233.2	0	99285
# 5	46599	17558.3	0	46599
# 6	28672	4389.6	0	28672
# 7	25114	1097.4	0	25114
# 8	21936	274.3	0	21936
# 9	20640	68.6	0	20359 281
# 10	18936	17.1	1	18187 749
# 11	16885	4.3	1	16276 609
# 12	15739	1.1	1	15370 369
# 13	14562	0.3	1	14229 333
# 14	13666	0.3	1	13374 292
# 15	12729	0.3	1	12470 259
# 16	11661	0.3	1	11383 278
# 17	10694	0.3	1	10457 237
# 18	9592	0.3	1	9353 239
# 19	7682	0.3	1	7513 169
# 20	7275	0.3	1	7111 164
# 21	6392	0.3	1	6253 139
# 22	5927	0.3	1	5793 134
# 23	5326	0.3	1	5214 112
# 24	5141	0.3	1	5007 134
# 25	4658	0.3	1	4539 119
# 26	4291	0.3	1	4188 103
# 27	3759	0.3	1	3656 103
# 28	3365	0.3	1	3277 88
# 29	2877	0.3	1	2803 74
# 30	2627	0.3	1	2530 97
# 31	2104	0.3	1	2052 52
# 32	1922	0.3	1	1875 47
# 33	1737	0.3	1	1701 36
# 34	1635	0.3	1	1588 47
# 35	1438	0.3	1	1395 43
# 36	1236	0.3	1	1200 36
# 37	1177	0.3	1	1134 43
# 38	982	0.3	1	941 41
# 39	854	0.3	1	830 24
# 40	704	0.3	1	676 28
# 41	595	0.3	1	572 23
# 42	553	0.3	1	532 21
# 43	439	0.3	1	424 15
# 44	404	0.3	1	375 29
# 45	386	0.3	1	372 14
# 46	307	0.3	1	296 11
# 47	288	0.3	1	253 35
# 48	274	0.3	1	253 21
# 49	238	0.3	1	222 16
# 50	184	0.3	1	166 18
# 51	164	0.3	1	160 4
# 52	137	0.3	1	121 16
# 53	109	0.3	1	90 19
# 54	81	0.3	1	68 13
# 55	74	0.3	1	66 8
# 56	95	0.3	1	73 22
# 57	76	0.3	1	55 21
# 58	74	0.3	1	52 22
# 59	65	0.3	1	48 17
# 60	46	0.3	1	26 20
# 61	42	0.3	1	32 10
# 62	37	0.3	1	26 11
#
# RUN STATISTICS FOR INPUT FILE: fastqs/ERR899435.fastq.gz
# =============================================
# 17899859 sequences processed in total
# Sequences removed because they became shorter than the length cutoff of 20 bp:	4261 (0.0%)
#
# 63	30	0.3	1	20 10
# 64	33	0.3	1	23 10
# 65	27	0.3	1	21 6
# 66	33	0.3	1	13 20
# 67	43	0.3	1	21 22
# 68	59	0.3	1	39 20
# 69	84	0.3	1	41 43
# 70	155	0.3	1	131 24
# 71	73	0.3	1	42 31
# 72	31	0.3	1	17 14
# 73	19	0.3	1	8 11
# 74	74	0.3	1	4 70
# 75	9	0.3	1	2 7
# 76	11	0.3	1	2 9
# 77	9	0.3	1	0 9
# 78	15	0.3	1	1 14
# 79	8	0.3	1	0 8
# 80	7	0.3	1	0 7
# 81	16	0.3	1	1 15
# 82	25	0.3	1	0 25
# 83	29	0.3	1	1 28
# 84	17	0.3	1	2 15
# 85	11	0.3	1	0 11
# 86	16	0.3	1	1 15
# 87	16	0.3	1	0 16
# 88	13	0.3	1	0 13
# 89	18	0.3	1	2 16
# 90	14	0.3	1	1 13
# 91	19	0.3	1	0 19
# 92	10	0.3	1	0 10
# 93	8	0.3	1	1 7
# 94	10	0.3	1	0 10
# 95	8	0.3	1	0 8
# 96	14	0.3	1	1 13
# 97	9	0.3	1	1 8
# 98	7	0.3	1	1 6
# 99	1	0.3	1	0 1
# 100	9	0.3	1	2 7
#
#
# RUN STATISTICS FOR INPUT FILE: fastqs/ERR899421.fastq.gz
# =============================================
# 17979693 sequences processed in total
# Sequences removed because they became shorter than the length cutoff of 20 bp:	2966 (0.0%)
#
# This is cutadapt 1.15 with Python 3.6.4
# Command line parameters: -f fastq -e 0.1 -q 20 -O 1 -a AGATCGGAAGAGC fastqs/ERR899432.fastq.gz
# Running on 1 core
# Trimming 1 adapter with at most 10.0% errors in single-end mode ...
# Finished in 638.53 s (35 us/read; 1.71 M reads/minute).
#
# === Summary ===
#
# Total reads processed:              18,211,995
# Reads with adapters:                 6,152,649 (33.8%)
# Reads written (passing filters):    18,211,995 (100.0%)
#
# Total basepairs processed: 1,821,199,500 bp
# Quality-trimmed:              18,756,852 bp (1.0%)
# Total written (filtered):  1,790,818,811 bp (98.3%)
#
# === Adapter 1 ===
#
# Sequence: AGATCGGAAGAGC; Type: regular 3'; Length: 13; Trimmed: 6152649 times.
#
# No. of allowed errors:
# 0-9 bp: 0; 10-13 bp: 1
#
# Bases preceding removed adapters:
# A: 29.0%
# C: 33.9%
# G: 18.9%
# T: 18.3%
# none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 1	4169023	4552998.8	0	4169023
# 2	1285762	1138249.7	0	1285762
# 3	339912	284562.4	0	339912
# 4	95916	71140.6	0	95916
# 5	41612	17785.2	0	41612
# 6	23375	4446.3	0	23375
# 7	20091	1111.6	0	20091
# 8	17379	277.9	0	17379
# 9	16200	69.5	0	15912 288
# 10	14337	17.4	1	13693 644
# 11	13241	4.3	1	12766 475
# 12	11895	1.1	1	11580 315
# 13	10630	0.3	1	10408 222
# 14	9875	0.3	1	9641 234
# 15	9004	0.3	1	8794 210
# 16	8207	0.3	1	7997 210
# 17	7429	0.3	1	7249 180
# 18	6490	0.3	1	6320 170
# 19	5244	0.3	1	5103 141
# 20	4844	0.3	1	4700 144
# 21	4291	0.3	1	4179 112
# 22	3910	0.3	1	3821 89
# 23	3483	0.3	1	3372 111
# 24	3233	0.3	1	3133 100
# 25	2944	0.3	1	2839 105
# 26	2685	0.3	1	2600 85
# 27	2428	0.3	1	2368 60
# 28	2036	0.3	1	1977 59
# 29	1665	0.3	1	1607 58
# 30	1679	0.3	1	1616 63
# 31	1266	0.3	1	1229 37
# 32	1141	0.3	1	1109 32
# 33	1019	0.3	1	992 27
# 34	1001	0.3	1	963 38
# 35	891	0.3	1	855 36
# 36	885	0.3	1	846 39
# 37	763	0.3	1	729 34
# 38	653	0.3	1	621 32
# 39	553	0.3	1	529 24
# 40	459	0.3	1	436 23
# 41	404	0.3	1	383 21
# 42	345	0.3	1	332 13
# 43	284	0.3	1	268 16
# 44	271	0.3	1	251 20
# 45	254	0.3	1	238 16
# 46	230	0.3	1	216 14
# 47	209	0.3	1	173 36
# 48	203	0.3	1	183 20
# 49	168	0.3	1	157 11
# 50	126	0.3	1	113 13
# 51	113	0.3	1	107 6
# 52	109	0.3	1	94 15
# 53	96	0.3	1	80 16
# 54	90	0.3	1	70 20
# 55	96	0.3	1	83 13
# 56	74	0.3	1	47 27
# 57	72	0.3	1	50 22
# 58	86	0.3	1	43 43
# 59	76	0.3	1	48 28
# 60	67	0.3	1	37 30
# 61	46	0.3	1	33 13
# 62	36	0.3	1	25 11
# 63	40	0.3	1	21 19
# 64	54	0.3	1	27 27
# 65	52	0.3	1	25 27
# 66	49	0.3	1	24 25
# 67	26	0.3	1	13 13
# 68	37	0.3	1	13 24
# 69	56	0.3	1	21 35
# 70	138	0.3	1	49 89
# 71	382	0.3	1	73 309
# 72	270	0.3	1	193 77
# 73	84	0.3	1	60 24
# 74	121	0.3	1	31 90
# 75	31	0.3	1	16 15
# 76	22	0.3	1	8 14
# 77	12	0.3	1	1 11
# 78	27	0.3	1	6 21
# 79	16	0.3	1	4 12
# 80	11	0.3	1	0 11
# 81	26	0.3	1	1 25
# 82	16	0.3	1	0 16
# 83	43	0.3	1	1 42
# 84	20	0.3	1	2 18
# 85	13	0.3	1	1 12
# 86	19	0.3	1	1 18
# 87	11	0.3	1	1 10
# 88	22	0.3	1	0 22
# 89	16	0.3	1	1 15
# 90	11	0.3	1	3 8
# 91	11	0.3	1	1 10
# 92	14	0.3	1	1 13
# 93	3	0.3	1	2 1
# 94	6	0.3	1	0 6
# 95	8	0.3	1	1 7
# 96	9	0.3	1	0 9
# 97	17	0.3	1	2 15
# 98	12	0.3	1	0 12
# 99	9	0.3	1	0 9
# 100	29	0.3	1	0 29
#
#
# RUN STATISTICS FOR INPUT FILE: fastqs/ERR899432.fastq.gz
# =============================================
# 18211995 sequences processed in total
# Sequences removed because they became shorter than the length cutoff of 20 bp:	3574 (0.0%)
#
# This is cutadapt 1.15 with Python 3.6.4
# Command line parameters: -f fastq -e 0.1 -q 20 -O 1 -a AGATCGGAAGAGC fastqs/ERR899423.fastq.gz
# Running on 1 core
# Trimming 1 adapter with at most 10.0% errors in single-end mode ...
# Finished in 641.94 s (35 us/read; 1.72 M reads/minute).
#
# === Summary ===
#
# Total reads processed:              18,424,646
# Reads with adapters:                 6,237,903 (33.9%)
# Reads written (passing filters):    18,424,646 (100.0%)
#
# Total basepairs processed: 1,842,464,600 bp
# Quality-trimmed:              18,809,376 bp (1.0%)
# Total written (filtered):  1,810,507,279 bp (98.3%)
#
# === Adapter 1 ===
#
# Sequence: AGATCGGAAGAGC; Type: regular 3'; Length: 13; Trimmed: 6237903 times.
#
# No. of allowed errors:
# 0-9 bp: 0; 10-13 bp: 1
#
# Bases preceding removed adapters:
# A: 28.0%
# C: 34.3%
# G: 19.8%
# T: 17.8%
# none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 1	4108616	4606161.5	0	4108616
# 2	1321696	1151540.4	0	1321696
# 3	349160	287885.1	0	349160
# 4	104164	71971.3	0	104164
# 5	49789	17992.8	0	49789
# 6	30589	4498.2	0	30589
# 7	26981	1124.6	0	26981
# 8	22969	281.1	0	22969
# 9	21073	70.3	0	20778 295
# 10	19544	17.6	1	18655 889
# 11	17137	4.4	1	16435 702
# 12	16195	1.1	1	15682 513
# 13	14441	0.3	1	14036 405
# 14	13566	0.3	1	13155 411
# 15	12811	0.3	1	12448 363
# ...
#
# This is cutadapt 1.15 with Python 3.6.4
# Command line parameters: -f fastq -e 0.1 -q 20 -O 1 -a AGATCGGAAGAGC fastqs/ERR899429.fastq.gz
# Running on 1 core
# Trimming 1 adapter with at most 10.0% errors in single-end mode ...
# Finished in 674.21 s (35 us/read; 1.72 M reads/minute).
#
# === Summary ===
#
# Total reads processed:              19,286,135
# Reads with adapters:                 6,570,339 (34.1%)
# Reads written (passing filters):    19,286,135 (100.0%)
#
# Total basepairs processed: 1,928,613,500 bp
# Quality-trimmed:              20,048,306 bp (1.0%)
# Total written (filtered):  1,893,114,468 bp (98.2%)
#
# === Adapter 1 ===
#
# Sequence: AGATCGGAAGAGC; Type: regular 3'; Length: 13; Trimmed: 6570339 times.
#
# No. of allowed errors:
# 0-9 bp: 0; 10-13 bp: 1
#
# Bases preceding removed adapters:
# A: 27.5%
# C: 34.4%
# G: 20.1%
# T: 18.1%
# none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 1	4245820	4821533.8	0	4245820
# 2	1372805	1205383.4	0	1372805
# 3	364128	301345.9	0	364128
# 4	111033	75336.5	0	111033
# 5	56311	18834.1	0	56311
# 6	36293	4708.5	0	36293
# 7	32495	1177.1	0	32495
# 8	28701	294.3	0	28701
# 9	27139	73.6	0	26830 309
# 10	25829	18.4	1	24609 1220
# 11	23270	4.6	1	22308 962
# 12	22111	1.1	1	21346 765
# 13	19969	0.3	1	19297 672
# 14	18741	0.3	1	18038 703
# 15	17796	0.3	1	17186 610
# 16	16538	0.3	1	15944 594
# 17	15340	0.3	1	14753 587
# 18	13837	0.3	1	13331 506
# 19	11485	0.3	1	11043 442
# 20	10754	0.3	1	10350 404
# 21	9696	0.3	1	9351 345
# 22	8901	0.3	1	8554 347
# 23	8121	0.3	1	7856 265
# 24	7578	0.3	1	7271 307
# 25	7133	0.3	1	6866 267
# 26	6607	0.3	1	6359 248
# 27	5808	0.3	1	5571 237
# 28	5192	0.3	1	4984 208
# 29	4609	0.3	1	4432 177
# 30	4186	0.3	1	3964 222
# 31	3507	0.3	1	3358 149
# 32	3048	0.3	1	2917 131
# 33	2742	0.3	1	2635 107
# 34	2577	0.3	1	2463 114
# 35	2430	0.3	1	2328 102
# 36	2240	0.3	1	2148 92
# 37	1910	0.3	1	1821 89
# 38	1629	0.3	1	1551 78
# 39	1421	0.3	1	1362 59
# 40	1170	0.3	1	1116 54
# 41	1026	0.3	1	985 41
# 42	880	0.3	1	841 39
# 43	775	0.3	1	748 27
# 44	678	0.3	1	629 49
# 45	658	0.3	1	627 31
# 46	624	0.3	1	593 31
# 47	490	0.3	1	438 52
# 48	458	0.3	1	429 29
# 49	373	0.3	1	349 24
# 50	306	0.3	1	286 20
# 51	277	0.3	1	260 17
# 52	236	0.3	1	219 17
# 53	186	0.3	1	159 27
# 54	152	0.3	1	142 10
# 55	132	0.3	1	113 19
# 56	173	0.3	1	117 56
# 57	137	0.3	1	111 26
# 58	161	0.3	1	113 48
# 59	102	0.3	1	73 29
# 60	80	0.3	1	54 26
# 61	83	0.3	1	62 21
# 62	52	0.3	1	32 20
# 63	65	0.3	1	48 17
# 64	63	0.3	1	55 8
# 65	42	0.3	1	24 18
# 66	42	0.3	1	19 23
# 67	53	0.3	1	24 29
# 68	62	0.3	1	35 27
# 69	127	0.3	1	51 76
# 70	190	0.3	1	148 42
# 71	102	0.3	1	63 39
# 72	36	0.3	1	19 17
# 73	21	0.3	1	12 9
# 74	153	0.3	1	16 137
# 75	16	0.3	1	6 10
# 76	11	0.3	1	2 9
# 77	11	0.3	1	0 11
# 78	18	0.3	1	1 17
# 79	14	0.3	1	2 12
# 80	11	0.3	1	0 11
# 81	10	0.3	1	2 8
# 82	28	0.3	1	2 26
# 83	44	0.3	1	2 42
# 84	11	0.3	1	2 9
# 85	29	0.3	1	2 27
# 86	28	0.3	1	2 26
# 87	15	0.3	1	0 15
# 88	31	0.3	1	1 30
# 89	31	0.3	1	3 28
# 90	17	0.3	1	0 17
# 91	10	0.3	1	0 10
# 92	19	0.3	1	1 18
# 93	6	0.3	1	0 6
# 94	8	0.3	1	0 8
# 95	15	0.3	1	1 14
# 96	17	0.3	1	0 17
# 97	13	0.3	1	2 11
# 98	7	0.3	1	2 5
# 99	3	0.3	1	1 2
# 100	21	0.3	1	0 21
#
#
# RUN STATISTICS FOR INPUT FILE: fastqs/ERR899429.fastq.gz
# =============================================
# 19286135 sequences processed in total
# Sequences removed because they became shorter than the length cutoff of 20 bp:	3490 (0.0%)
#
# This is cutadapt 1.15 with Python 3.6.4
# Command line parameters: -f fastq -e 0.1 -q 20 -O 1 -a AGATCGGAAGAGC fastqs/ERR899431.fastq.gz
# Running on 1 core
# Trimming 1 adapter with at most 10.0% errors in single-end mode ...
# Finished in 680.47 s (35 us/read; 1.71 M reads/minute).
#
# === Summary ===
#
# Total reads processed:              19,419,534
# Reads with adapters:                 6,524,686 (33.6%)
# Reads written (passing filters):    19,419,534 (100.0%)
#
# Total basepairs processed: 1,941,953,400 bp
# Quality-trimmed:              20,129,271 bp (1.0%)
# Total written (filtered):  1,908,473,401 bp (98.3%)
#
# === Adapter 1 ===
#
# Sequence: AGATCGGAAGAGC; Type: regular 3'; Length: 13; Trimmed: 6524686 times.
#
# No. of allowed errors:
# 0-9 bp: 0; 10-13 bp: 1
#
# Bases preceding removed adapters:
# A: 28.3%
# C: 34.1%
# G: 19.8%
# T: 17.8%
# none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 1	4331832	4854883.5	0	4331832
# 2	1380178	1213720.9	0	1380178
# 3	363263	303430.2	0	363263
# 4	104304	75857.6	0	104304
# 5	48442	18964.4	0	48442
# 6	28512	4741.1	0	28512
# 7	24806	1185.3	0	24806
# 8	22042	296.3	0	22042
# 9	20509	74.1	0	20201 308
# 10	19132	18.5	1	18223 909
# 11	17136	4.6	1	16392 744
# 12	16188	1.2	1	15703 485
# 13	14059	0.3	1	13669 390
# 14	13349	0.3	1	12961 388
# 15	12388	0.3	1	12017 371
# 16	11426	0.3	1	11093 333
# 17	10204	0.3	1	9884 320
# 18	9331	0.3	1	9080 251
# 19	7583	0.3	1	7372 211
# 20	7318	0.3	1	7040 278
# 21	6496	0.3	1	6275 221
# 22	5793	0.3	1	5597 196
# 23	5161	0.3	1	4992 169
# 24	4875	0.3	1	4718 157
# 25	4482	0.3	1	4327 155
# 26	3972	0.3	1	3839 133
# 27	3621	0.3	1	3489 132
# 28	3187	0.3	1	3094 93
# 29	2760	0.3	1	2672 88
# 30	2534	0.3	1	2404 130
# 31	2080	0.3	1	2006 74
# 32	1915	0.3	1	1843 72
# 33	1648	0.3	1	1606 42
# 34	1564	0.3	1	1511 53
# 35	1386	0.3	1	1336 50
# 36	1256	0.3	1	1203 53
# 37	1099	0.3	1	1045 54
# 38	968	0.3	1	926 42
# 39	781	0.3	1	747 34
# 40	734	0.3	1	685 49
# 41	591	0.3	1	554 37
# 42	522	0.3	1	502 20
# 43	450	0.3	1	428 22
# 44	416	0.3	1	393 23
# 45	395	0.3	1	364 31
# 46	351	0.3	1	334 17
# 47	301	0.3	1	272 29
# 48	277	0.3	1	261 16
# 49	267	0.3	1	252 15
# 50	216	0.3	1	195 21
# 51	160	0.3	1	146 14
# 52	161	0.3	1	134 27
# 53	163	0.3	1	142 21
# 54	98	0.3	1	91 7
# 55	101	0.3	1	93 8
# 56	116	0.3	1	81 35
# 57	93	0.3	1	74 19
# 58	114	0.3	1	74 40
# 59	86	0.3	1	67 19
# 60	75	0.3	1	51 24
# 61	52	0.3	1	38 14
# 62	48	0.3	1	35 13
# 63	48	0.3	1	38 10
# 64	48	0.3	1	31 17
# 65	44	0.3	1	28 16
# 66	39	0.3	1	18 21
# 67	59	0.3	1	29 30
# 68	79	0.3	1	34 45
# 69	130	0.3	1	51 79
# 70	232	0.3	1	177 55
# 71	91	0.3	1	51 40
# 72	29	0.3	1	19 10
# 73	16	0.3	1	7 9
# 74	120	0.3	1	4 116
# 75	11	0.3	1	3 8
# 76	13	0.3	1	3 10
# 77	12	0.3	1	3 9
# 78	15	0.3	1	0 15
# 79	11	0.3	1	2 9
# 80	12	0.3	1	0 12
# 81	14	0.3	1	1 13
# 82	19	0.3	1	0 19
# 83	36	0.3	1	0 36
# 84	7	0.3	1	1 6
# 85	15	0.3	1	2 13
# 86	29	0.3	1	0 29
# 87	16	0.3	1	0 16
# 88	25	0.3	1	1 24
# 89	22	0.3	1	2 20
# 90	10	0.3	1	0 10
# 91	22	0.3	1	0 22
# 92	13	0.3	1	1 12
# 93	8	0.3	1	2 6
# 94	9	0.3	1	1 8
# 95	13	0.3	1	0 13
# 96	16	0.3	1	3 13
# 97	8	0.3	1	1 7
# 98	5	0.3	1	0 5
# 99	7	0.3	1	1 6
# 100	16	0.3	1	3 13
#
#
# RUN STATISTICS FOR INPUT FILE: fastqs/ERR899431.fastq.gz
# =============================================
# 19419534 sequences processed in total
# Sequences removed because they became shorter than the length cutoff of 20 bp:	3370 (0.0%)
#
# This is cutadapt 1.15 with Python 3.6.4
# Command line parameters: -f fastq -e 0.1 -q 20 -O 1 -a AGATCGGAAGAGC fastqs/ERR899433.fastq.gz
# Running on 1 core
# Trimming 1 adapter with at most 10.0% errors in single-end mode ...
# Finished in 689.04 s (35 us/read; 1.73 M reads/minute).
#
# === Summary ===
#
# Total reads processed:              19,836,280
# Reads with adapters:                 6,642,538 (33.5%)
# Reads written (passing filters):    19,836,280 (100.0%)
#
# Total basepairs processed: 1,983,628,000 bp
# Quality-trimmed:              21,037,203 bp (1.1%)
# Total written (filtered):  1,949,461,620 bp (98.3%)
#
# === Adapter 1 ===
#
# Sequence: AGATCGGAAGAGC; Type: regular 3'; Length: 13; Trimmed: 6642538 times.
#
# No. of allowed errors:
# 0-9 bp: 0; 10-13 bp: 1
#
# Bases preceding removed adapters:
# A: 28.6%
# C: 34.0%
# G: 19.5%
# T: 17.8%
# none/other: 0.1%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 1	4455569	4959070.0	0	4455569
# 2	1408746	1239767.5	0	1408746
# 3	369105	309941.9	0	369105
# 4	105047	77485.5	0	105047
# 5	46755	19371.4	0	46755
# 6	26929	4842.8	0	26929
# 7	22422	1210.7	0	22422
# 8	19471	302.7	0	19471
# 9	18606	75.7	0	18277 329
# 10	16845	18.9	1	16140 705
# 11	14830	4.7	1	14291 539
# 12	13521	1.2	1	13236 285
# 13	12158	0.3	1	11911 247
# 14	11269	0.3	1	11064 205
# 15	10269	0.3	1	10062 207
# 16	9389	0.3	1	9188 201
# 17	8334	0.3	1	8137 197
# 18	7704	0.3	1	7549 155
# 19	6046	0.3	1	5928 118
# 20	5460	0.3	1	5330 130
# 21	5090	0.3	1	4975 115
# 22	4253	0.3	1	4128 125
# 23	4088	0.3	1	3976 112
# 24	3865	0.3	1	3755 110
# 25	3314	0.3	1	3227 87
# 26	3109	0.3	1	3035 74
# 27	2741	0.3	1	2673 68
# 28	2457	0.3	1	2394 63
# 29	2175	0.3	1	2118 57
# 30	1950	0.3	1	1872 78
# 31	1543	0.3	1	1507 36
# 32	1434	0.3	1	1386 48
# 33	1198	0.3	1	1174 24
# 34	1145	0.3	1	1106 39
# 35	1031	0.3	1	988 43
# 36	989	0.3	1	954 35
# 37	875	0.3	1	837 38
# 38	725	0.3	1	694 31
# 39	699	0.3	1	670 29
# 40	554	0.3	1	527 27
# 41	475	0.3	1	454 21
# 42	422	0.3	1	402 20
# 43	367	0.3	1	344 23
# 44	373	0.3	1	334 39
# 45	343	0.3	1	306 37
# 46	339	0.3	1	307 32
# 47	268	0.3	1	220 48
# 48	229	0.3	1	202 27
# 49	216	0.3	1	193 23
# 50	207	0.3	1	173 34
# 51	154	0.3	1	134 20
# 52	203	0.3	1	149 54
# 53	151	0.3	1	129 22
# 54	109	0.3	1	86 23
# 55	111	0.3	1	77 34
# 56	119	0.3	1	58 61
# 57	126	0.3	1	65 61
# 58	137	0.3	1	54 83
# 59	98	0.3	1	57 41
# 60	96	0.3	1	35 61
# 61	80	0.3	1	39 41
# 62	193	0.3	1	26 167
# 63	186	0.3	1	45 141
# 64	92	0.3	1	41 51
# 65	70	0.3	1	16 54
# 66	160	0.3	1	16 144
# 67	375	0.3	1	31 344
# 68	508	0.3	1	45 463
# 69	2147	0.3	1	81 2066
# 70	939	0.3	1	166 773
# 71	388	0.3	1	50 338
# 72	100	0.3	1	22 78
# 73	46	0.3	1	12 34
# 74	133	0.3	1	14 119
# 75	20	0.3	1	2 18
# 76	22	0.3	1	0 22
# 77	24	0.3	1	4 20
# 78	35	0.3	1	1 34
# 79	38	0.3	1	2 36
# 80	18	0.3	1	1 17
# 81	23	0.3	1	1 22
# 82	33	0.3	1	0 33
# 83	39	0.3	1	0 39
# 84	22	0.3	1	1 21
# 85	18	0.3	1	0 18
# 86	26	0.3	1	0 26
# 87	20	0.3	1	0 20
# 88	35	0.3	1	1 34
# 89	23	0.3	1	2 21
# 90	18	0.3	1	0 18
# 91	27	0.3	1	4 23
# 92	18	0.3	1	2 16
# 93	20	0.3	1	1 19
# 94	21	0.3	1	0 21
# 95	20	0.3	1	3 17
# 96	20	0.3	1	1 19
# 97	22	0.3	1	1 21
# 98	34	0.3	1	1 33
# 99	34	0.3	1	1 33
# 100	238	0.3	1	0 238
#
#
# RUN STATISTICS FOR INPUT FILE: fastqs/ERR899433.fastq.gz
# =============================================
# 19836280 sequences processed in total
# Sequences removed because they became shorter than the length cutoff of 20 bp:	8673 (0.0%)
#
# 20000000 sequences processed
# 20000000 sequences processed
# This is cutadapt 1.15 with Python 3.6.4
# Command line parameters: -f fastq -e 0.1 -q 20 -O 1 -a AGATCGGAAGAGC fastqs/ERR899425.fastq.gz
# Running on 1 core
# Trimming 1 adapter with at most 10.0% errors in single-end mode ...
# Finished in 712.22 s (34 us/read; 1.74 M reads/minute).
#
# === Summary ===
#
# Total reads processed:              20,649,441
# Reads with adapters:                 6,994,289 (33.9%)
# Reads written (passing filters):    20,649,441 (100.0%)
#
# Total basepairs processed: 2,064,944,100 bp
# Quality-trimmed:              22,041,136 bp (1.1%)
# Total written (filtered):  2,027,967,524 bp (98.2%)
#
# === Adapter 1 ===
#
# Sequence: AGATCGGAAGAGC; Type: regular 3'; Length: 13; Trimmed: 6994289 times.
#
# No. of allowed errors:
# 0-9 bp: 0; 10-13 bp: 1
#
# Bases preceding removed adapters:
# A: 27.8%
# C: 34.6%
# G: 19.7%
# T: 17.8%
# none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 1	4592437	5162360.2	0	4592437
# 2	1475602	1290590.1	0	1475602
# 3	391811	322647.5	0	391811
# 4	118840	80661.9	0	118840
# 5	57715	20165.5	0	57715
# 6	36313	5041.4	0	36313
# 7	31605	1260.3	0	31605
# 8	27203	315.1	0	27203
# 9	25316	78.8	0	25004 312
# 10	23304	19.7	1	22206 1098
# 11	20846	4.9	1	19907 939
# 12	19258	1.2	1	18592 666
# 13	17279	0.3	1	16722 557
# 14	16303	0.3	1	15769 534
# 15	14954	0.3	1	14485 469
# 16	13868	0.3	1	13400 468
# 17	12071	0.3	1	11681 390
# 18	10609	0.3	1	10229 380
# 19	8899	0.3	1	8610 289
# 20	8063	0.3	1	7765 298
# 21	7058	0.3	1	6817 241
# 22	6591	0.3	1	6336 255
# 23	5778	0.3	1	5566 212
# 24	5250	0.3	1	5057 193
# 25	4966	0.3	1	4768 198
# 26	4328	0.3	1	4182 146
# 27	3998	0.3	1	3854 144
# 28	3524	0.3	1	3396 128
# 29	2996	0.3	1	2888 108
# 30	2861	0.3	1	2735 126
# 31	2219	0.3	1	2137 82
# 32	2022	0.3	1	1935 87
# 33	1757	0.3	1	1703 54
# 34	1639	0.3	1	1580 59
# 35	1546	0.3	1	1463 83
# 36	1404	0.3	1	1351 53
# 37	1183	0.3	1	1135 48
# 38	1124	0.3	1	1068 56
# 39	940	0.3	1	892 48
# 40	859	0.3	1	821 38
# 41	750	0.3	1	715 35
# 42	610	0.3	1	585 25
# 43	524	0.3	1	491 33
# 44	466	0.3	1	438 28
# 45	498	0.3	1	465 33
# 46	373	0.3	1	349 24
# 47	399	0.3	1	352 47
# 48	360	0.3	1	341 19
# 49	314	0.3	1	273 41
# 50	295	0.3	1	252 43
# 51	213	0.3	1	196 17
# 52	185	0.3	1	158 27
# 53	180	0.3	1	164 16
# 54	143	0.3	1	125 18
# 55	122	0.3	1	110 12
# 56	148	0.3	1	88 60
# 57	124	0.3	1	98 26
# 58	147	0.3	1	82 65
# 59	98	0.3	1	75 23
# 60	109	0.3	1	77 32
# 61	80	0.3	1	61 19
# 62	64	0.3	1	40 24
# 63	63	0.3	1	44 19
# 64	96	0.3	1	38 58
# 65	96	0.3	1	48 48
# 66	78	0.3	1	45 33
# 67	72	0.3	1	23 49
# 68	95	0.3	1	27 68
# 69	195	0.3	1	29 166
# 70	328	0.3	1	58 270
# 71	1114	0.3	1	94 1020
# 72	460	0.3	1	256 204
# 73	178	0.3	1	79 99
# 74	196	0.3	1	35 161
# 75	36	0.3	1	14 22
# 76	37	0.3	1	17 20
# 77	33	0.3	1	4 29
# 78	53	0.3	1	1 52
# 79	33	0.3	1	3 30
# 80	23	0.3	1	1 22
# 81	26	0.3	1	0 26
# 82	26	0.3	1	2 24
# 83	54	0.3	1	2 52
# 84	20	0.3	1	3 17
# 85	22	0.3	1	0 22
# 86	38	0.3	1	1 37
# 87	11	0.3	1	2 9
# 88	36	0.3	1	0 36
# 89	32	0.3	1	1 31
# 90	16	0.3	1	4 12
# 91	25	0.3	1	1 24
# 92	19	0.3	1	2 17
# 93	15	0.3	1	2 13
# 94	16	0.3	1	2 14
# 95	21	0.3	1	2 19
# 96	33	0.3	1	1 32
# 97	14	0.3	1	1 13
# 98	9	0.3	1	0 9
# 99	22	0.3	1	0 22
# 100	107	0.3	1	1 106
#
#
# RUN STATISTICS FOR INPUT FILE: fastqs/ERR899425.fastq.gz
# =============================================
# 20649441 sequences processed in total
# Sequences removed because they became shorter than the length cutoff of 20 bp:	6168 (0.0%)
#
# This is cutadapt 1.15 with Python 3.6.4
# Command line parameters: -f fastq -e 0.1 -q 20 -O 1 -a AGATCGGAAGAGC fastqs/ERR899438.fastq.gz
# Running on 1 core
# Trimming 1 adapter with at most 10.0% errors in single-end mode ...
# Finished in 728.41 s (34 us/read; 1.75 M reads/minute).
#
# === Summary ===
#
# Total reads processed:              21,276,620
# Reads with adapters:                 7,144,739 (33.6%)
# Reads written (passing filters):    21,276,620 (100.0%)
#
# Total basepairs processed: 2,127,662,000 bp
# Quality-trimmed:              22,734,253 bp (1.1%)
# Total written (filtered):  2,090,306,686 bp (98.2%)
#
# === Adapter 1 ===
#
# Sequence: AGATCGGAAGAGC; Type: regular 3'; Length: 13; Trimmed: 7144739 times.
#
# No. of allowed errors:
# 0-9 bp: 0; 10-13 bp: 1
#
# Bases preceding removed adapters:
# A: 28.3%
# C: 33.8%
# G: 19.9%
# T: 18.0%
# none/other: 0.0%
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 1	4749257	5319155.0	0	4749257
# 2	1503864	1329788.8	0	1503864
# 3	400899	332447.2	0	400899
# 4	117278	83111.8	0	117278
# 5	53552	20777.9	0	53552
# 6	32328	5194.5	0	32328
# 7	28091	1298.6	0	28091
# 8	24213	324.7	0	24213
# 9	22601	81.2	0	22256 345
# 10	20924	20.3	1	20187 737
# 11	18300	5.1	1	17760 540
# 12	17025	1.3	1	16710 315
# 13	15151	0.3	1	14879 272
# 14	14218	0.3	1	13942 276
# 15	12870	0.3	1	12636 234
# 16	11654	0.3	1	11450 204
# 17	10637	0.3	1	10433 204
# 18	9495	0.3	1	9322 173
# 19	7865	0.3	1	7712 153
# 20	7068	0.3	1	6895 173
# 21	6457	0.3	1	6334 123
# 22	5869	0.3	1	5716 153
# 23	5282	0.3	1	5157 125
# 24	4862	0.3	1	4774 88
# 25	4532	0.3	1	4428 104
# 26	3978	0.3	1	3895 83
# 27	3581	0.3	1	3493 88
# 28	3183	0.3	1	3112 71
# 29	2764	0.3	1	2703 61
# 30	2679	0.3	1	2573 106
# 31	2022	0.3	1	1980 42
# 32	1990	0.3	1	1943 47
# 33	1792	0.3	1	1758 34
# 34	1614	0.3	1	1569 45
# 35	1487	0.3	1	1446 41
# 36	1435	0.3	1	1381 54
# 37	1214	0.3	1	1172 42
# 38	1100	0.3	1	1063 37
# 39	957	0.3	1	934 23
# 40	909	0.3	1	875 34
# 41	743	0.3	1	731 12
# 42	610	0.3	1	590 20
# 43	607	0.3	1	582 25
# 44	517	0.3	1	484 33
# 45	520	0.3	1	490 30
# 46	487	0.3	1	465 22
# 47	438	0.3	1	401 37
# 48	449	0.3	1	416 33
# 49	366	0.3	1	336 30
# 50	290	0.3	1	270 20
# 51	262	0.3	1	249 13
# 52	240	0.3	1	223 17
# 53	241	0.3	1	219 22
# 54	157	0.3	1	141 16
# 55	165	0.3	1	157 8
# 56	166	0.3	1	114 52
# 57	139	0.3	1	114 25
# 58	181	0.3	1	133 48
# 59	143	0.3	1	120 23
# 60	121	0.3	1	89 32
# 61	112	0.3	1	94 18
# 62	113	0.3	1	68 45
# 63	130	0.3	1	86 44
# 64	83	0.3	1	64 19
# 65	52	0.3	1	39 13
# 66	90	0.3	1	41 49
# 67	121	0.3	1	39 82
# 68	201	0.3	1	58 143
# 69	653	0.3	1	91 562
# 70	407	0.3	1	224 183
# 71	142	0.3	1	67 75
# 72	73	0.3	1	46 27
# 73	26	0.3	1	13 13
# 74	121	0.3	1	6 115
# 75	11	0.3	1	4 7
# 76	20	0.3	1	4 16
# 77	25	0.3	1	2 23
# 78	22	0.3	1	3 19
# 79	18	0.3	1	1 17
# 80	20	0.3	1	0 20
# 81	25	0.3	1	0 25
# 82	25	0.3	1	0 25
# 83	46	0.3	1	0 46
# 84	14	0.3	1	2 12
# 85	17	0.3	1	1 16
# 86	45	0.3	1	1 44
# 87	20	0.3	1	1 19
# 88	34	0.3	1	1 33
# 89	23	0.3	1	2 21
# 90	13	0.3	1	0 13
# 91	26	0.3	1	1 25
# 92	20	0.3	1	2 18
# 93	17	0.3	1	3 14
# 94	14	0.3	1	0 14
# 95	9	0.3	1	0 9
# 96	8	0.3	1	0 8
# 97	11	0.3	1	0 11
# 98	13	0.3	1	0 13
# 99	16	0.3	1	0 16
# 100	64	0.3	1	0 64
#
#
# RUN STATISTICS FOR INPUT FILE: fastqs/ERR899438.fastq.gz
# =============================================
# 21276620 sequences processed in total
# Sequences removed because they became shorter than the length cutoff of 20 bp:	4782 (0.0%)

# %%
#fastqc of sequencing reads

old_cmd = '''
#load fastqc
module load fastqc

fqs=""

for basename in $(ls $FASTQS | cut -f1 -d '.'); do
    #basename=$(echo $fq | cut -f1 -d '.')
    fqd=$FASTQS
    fq1=".fastq.gz"
    fq1=$fqd/$basename$fq1
    fqs="$fqs $fq1"
    
done

for basename in $(ls $PFASTQS | cut -f1 -d '_' | sort | uniq); do
    echo $basename
    fqd=$PFASTQS
    fq1="_1.fastq.gz"
    fq2="_2.fastq.gz"
    fq1=$fqd/$basename$fq1
    fq2=$fqd/$basename$fq2
    fqs="$fqs $fq1 $fq2"
done

echo "Performing FastQC for $fqs"
fastqc --threads $MAXCORES $fqs -o $FASTQCOUT
'''
#out = run_cmd(cmd)

fastq_files = glob.glob(FASTQS+"/*.fastq.gz") 
print(fastq_files)
cmds = []
for fastq_file in fastq_files:
    cmds.append(ENVCMD + " && " +
                "module load fastqc && " +
                "fastqc " + 
                fastq_file +
                " -o " + FASTQCOUT)

pool = Pool(processes=MAXCORES)
results = pool.map_async(run_cmd, cmds)
pool.close()
pool.join()
pool.terminate()
# Out:
# ['fastqs/ERR899426.fastq.gz', 'fastqs/ERR899430.fastq.gz', 'fastqs/ERR899435.fastq.gz', 'fastqs/ERR899431.fastq.gz', 'fastqs/ERR899428.fastq.gz', 'fastqs/ERR899436.fastq.gz', 'fastqs/ERR899425.fastq.gz', 'fastqs/ERR899427.fastq.gz', 'fastqs/ERR899433.fastq.gz', 'fastqs/ERR899438.fastq.gz', 'fastqs/ERR899437.fastq.gz', 'fastqs/ERR899422.fastq.gz', 'fastqs/ERR899432.fastq.gz', 'fastqs/ERR899434.fastq.gz', 'fastqs/ERR899421.fastq.gz', 'fastqs/ERR899423.fastq.gz', 'fastqs/ERR899424.fastq.gz', 'fastqs/ERR899429.fastq.gz']
# Started analysis of ERR899438.fastq.gz
# Started analysis of ERR899425.fastq.gz
# Started analysis of ERR899435.fastq.gz
# Started analysis of ERR899426.fastq.gz
# Started analysis of ERR899429.fastq.gz
# Started analysis of ERR899423.fastq.gz
# Started analysis of ERR899433.fastq.gz
# Started analysis of ERR899421.fastq.gz
# Started analysis of ERR899424.fastq.gz
# Started analysis of ERR899428.fastq.gz
# Started analysis of ERR899431.fastq.gz
# Started analysis of ERR899422.fastq.gz
# Started analysis of ERR899437.fastq.gz
# Started analysis of ERR899430.fastq.gz
# Started analysis of ERR899427.fastq.gz
# Started analysis of ERR899434.fastq.gz
# Started analysis of ERR899432.fastq.gz
# Started analysis of ERR899436.fastq.gz
# Approx 5% complete for ERR899428.fastq.gz
# Approx 5% complete for ERR899427.fastq.gz
# Approx 5% complete for ERR899437.fastq.gz
# Approx 5% complete for ERR899432.fastq.gz
# Approx 5% complete for ERR899423.fastq.gz
# Approx 5% complete for ERR899421.fastq.gz
# Approx 5% complete for ERR899436.fastq.gz
# Approx 5% complete for ERR899435.fastq.gz
# Approx 5% complete for ERR899434.fastq.gz
# Approx 5% complete for ERR899429.fastq.gz
# Approx 5% complete for ERR899422.fastq.gz
# Approx 5% complete for ERR899426.fastq.gz
# Approx 5% complete for ERR899424.fastq.gz
# Approx 5% complete for ERR899430.fastq.gz
# Approx 5% complete for ERR899431.fastq.gz
# Approx 5% complete for ERR899433.fastq.gz
# Approx 5% complete for ERR899425.fastq.gz
# Approx 5% complete for ERR899438.fastq.gz
# Approx 10% complete for ERR899427.fastq.gz
# Approx 10% complete for ERR899428.fastq.gz
# Approx 10% complete for ERR899437.fastq.gz
# Approx 10% complete for ERR899432.fastq.gz
# Approx 10% complete for ERR899436.fastq.gz
# Approx 10% complete for ERR899423.fastq.gz
# Approx 10% complete for ERR899435.fastq.gz
# Approx 10% complete for ERR899421.fastq.gz
# Approx 10% complete for ERR899434.fastq.gz
# Approx 10% complete for ERR899422.fastq.gz
# Approx 10% complete for ERR899429.fastq.gz
# Approx 10% complete for ERR899426.fastq.gz
# Approx 10% complete for ERR899430.fastq.gz
# Approx 10% complete for ERR899431.fastq.gz
# Approx 10% complete for ERR899424.fastq.gz
# Approx 10% complete for ERR899433.fastq.gz
# Approx 10% complete for ERR899425.fastq.gz
# Approx 10% complete for ERR899438.fastq.gz
# Approx 15% complete for ERR899427.fastq.gz
# Approx 15% complete for ERR899428.fastq.gz
# Approx 15% complete for ERR899432.fastq.gz
# Approx 15% complete for ERR899436.fastq.gz
# Approx 15% complete for ERR899435.fastq.gz
# Approx 15% complete for ERR899437.fastq.gz
# Approx 15% complete for ERR899434.fastq.gz
# Approx 15% complete for ERR899421.fastq.gz
# Approx 15% complete for ERR899423.fastq.gz
# Approx 15% complete for ERR899422.fastq.gz
# Approx 15% complete for ERR899429.fastq.gz
# Approx 15% complete for ERR899430.fastq.gz
# Approx 15% complete for ERR899426.fastq.gz
# Approx 15% complete for ERR899431.fastq.gz
# Approx 15% complete for ERR899424.fastq.gz
# Approx 15% complete for ERR899433.fastq.gz
# Approx 15% complete for ERR899425.fastq.gz
# Approx 15% complete for ERR899438.fastq.gz
# Approx 20% complete for ERR899427.fastq.gz
# Approx 20% complete for ERR899428.fastq.gz
# Approx 20% complete for ERR899435.fastq.gz
# Approx 20% complete for ERR899432.fastq.gz
# Approx 20% complete for ERR899436.fastq.gz
# Approx 20% complete for ERR899437.fastq.gz
# Approx 20% complete for ERR899434.fastq.gz
# Approx 20% complete for ERR899421.fastq.gz
# Approx 20% complete for ERR899423.fastq.gz
# Approx 20% complete for ERR899422.fastq.gz
# Approx 20% complete for ERR899429.fastq.gz
# Approx 20% complete for ERR899430.fastq.gz
# Approx 20% complete for ERR899426.fastq.gz
# Approx 20% complete for ERR899431.fastq.gz
# Approx 20% complete for ERR899424.fastq.gz
# Approx 20% complete for ERR899433.fastq.gz
# Approx 20% complete for ERR899425.fastq.gz
# Approx 20% complete for ERR899438.fastq.gz
# Approx 25% complete for ERR899427.fastq.gz
# Approx 25% complete for ERR899428.fastq.gz
# Approx 25% complete for ERR899435.fastq.gz
# Approx 25% complete for ERR899432.fastq.gz
# Approx 25% complete for ERR899436.fastq.gz
# Approx 25% complete for ERR899434.fastq.gz
# Approx 25% complete for ERR899437.fastq.gz
# Approx 25% complete for ERR899421.fastq.gz
# Approx 25% complete for ERR899423.fastq.gz
# Approx 25% complete for ERR899422.fastq.gz
# Approx 25% complete for ERR899429.fastq.gz
# Approx 25% complete for ERR899430.fastq.gz
# Approx 25% complete for ERR899426.fastq.gz
# Approx 25% complete for ERR899431.fastq.gz
# Approx 25% complete for ERR899424.fastq.gz
# Approx 25% complete for ERR899433.fastq.gz
# Approx 25% complete for ERR899425.fastq.gz
# Approx 30% complete for ERR899427.fastq.gz
# Approx 30% complete for ERR899428.fastq.gz
# Approx 25% complete for ERR899438.fastq.gz
# Approx 30% complete for ERR899435.fastq.gz
# Approx 30% complete for ERR899432.fastq.gz
# Approx 30% complete for ERR899436.fastq.gz
# Approx 30% complete for ERR899434.fastq.gz
# Approx 30% complete for ERR899421.fastq.gz
# Approx 30% complete for ERR899437.fastq.gz
# Approx 30% complete for ERR899423.fastq.gz
# Approx 30% complete for ERR899422.fastq.gz
# Approx 30% complete for ERR899429.fastq.gz
# Approx 30% complete for ERR899430.fastq.gz
# Approx 30% complete for ERR899426.fastq.gz
# Approx 30% complete for ERR899431.fastq.gz
# Approx 30% complete for ERR899424.fastq.gz
# Approx 30% complete for ERR899433.fastq.gz
# Approx 35% complete for ERR899427.fastq.gz
# Approx 35% complete for ERR899428.fastq.gz
# Approx 30% complete for ERR899425.fastq.gz
# Approx 35% complete for ERR899435.fastq.gz
# Approx 35% complete for ERR899432.fastq.gz
# Approx 35% complete for ERR899436.fastq.gz
# Approx 35% complete for ERR899434.fastq.gz
# Approx 35% complete for ERR899421.fastq.gz
# Approx 30% complete for ERR899438.fastq.gz
# Approx 35% complete for ERR899437.fastq.gz
# Approx 35% complete for ERR899423.fastq.gz
# Approx 35% complete for ERR899422.fastq.gz
# Approx 35% complete for ERR899429.fastq.gz
# Approx 35% complete for ERR899430.fastq.gz
# Approx 35% complete for ERR899426.fastq.gz
# Approx 35% complete for ERR899431.fastq.gz
# Approx 35% complete for ERR899424.fastq.gz
# Approx 40% complete for ERR899427.fastq.gz
# Approx 40% complete for ERR899428.fastq.gz
# Approx 35% complete for ERR899433.fastq.gz
# Approx 35% complete for ERR899425.fastq.gz
# Approx 40% complete for ERR899432.fastq.gz
# Approx 40% complete for ERR899435.fastq.gz
# Approx 40% complete for ERR899436.fastq.gz
# Approx 40% complete for ERR899434.fastq.gz
# Approx 40% complete for ERR899421.fastq.gz
# Approx 40% complete for ERR899437.fastq.gz
# Approx 40% complete for ERR899423.fastq.gz
# Approx 40% complete for ERR899422.fastq.gz
# Approx 35% complete for ERR899438.fastq.gz
# Approx 40% complete for ERR899429.fastq.gz
# Approx 40% complete for ERR899430.fastq.gz
# Approx 40% complete for ERR899426.fastq.gz
# Approx 40% complete for ERR899431.fastq.gz
# Approx 45% complete for ERR899427.fastq.gz
# Approx 45% complete for ERR899428.fastq.gz
# Approx 40% complete for ERR899424.fastq.gz
# Approx 40% complete for ERR899433.fastq.gz
# Approx 45% complete for ERR899432.fastq.gz
# Approx 45% complete for ERR899435.fastq.gz
# Approx 45% complete for ERR899436.fastq.gz
# Approx 40% complete for ERR899425.fastq.gz
# Approx 45% complete for ERR899434.fastq.gz
# Approx 45% complete for ERR899421.fastq.gz
# Approx 45% complete for ERR899437.fastq.gz
# Approx 45% complete for ERR899423.fastq.gz
# Approx 45% complete for ERR899422.fastq.gz
# Approx 45% complete for ERR899429.fastq.gz
# Approx 40% complete for ERR899438.fastq.gz
# Approx 45% complete for ERR899430.fastq.gz
# Approx 50% complete for ERR899427.fastq.gz
# Approx 50% complete for ERR899428.fastq.gz
# Approx 45% complete for ERR899426.fastq.gz
# Approx 45% complete for ERR899431.fastq.gz
# Approx 45% complete for ERR899424.fastq.gz
# Approx 45% complete for ERR899433.fastq.gz
# Approx 50% complete for ERR899432.fastq.gz
# Approx 50% complete for ERR899435.fastq.gz
# Approx 50% complete for ERR899436.fastq.gz
# Approx 50% complete for ERR899434.fastq.gz
# Approx 50% complete for ERR899421.fastq.gz
# Approx 45% complete for ERR899425.fastq.gz
# Approx 50% complete for ERR899437.fastq.gz
# Approx 50% complete for ERR899423.fastq.gz
# Approx 50% complete for ERR899422.fastq.gz
# Approx 50% complete for ERR899429.fastq.gz
# Approx 55% complete for ERR899427.fastq.gz
# Approx 50% complete for ERR899430.fastq.gz
# Approx 55% complete for ERR899428.fastq.gz
# Approx 45% complete for ERR899438.fastq.gz
# Approx 50% complete for ERR899426.fastq.gz
# Approx 50% complete for ERR899431.fastq.gz
# Approx 50% complete for ERR899424.fastq.gz
# Approx 55% complete for ERR899432.fastq.gz
# Approx 55% complete for ERR899435.fastq.gz
# Approx 50% complete for ERR899433.fastq.gz
# Approx 55% complete for ERR899434.fastq.gz
# Approx 55% complete for ERR899436.fastq.gz
# Approx 55% complete for ERR899421.fastq.gz
# Approx 55% complete for ERR899423.fastq.gz
# Approx 55% complete for ERR899437.fastq.gz
# Approx 50% complete for ERR899425.fastq.gz
# Approx 55% complete for ERR899422.fastq.gz
# Approx 60% complete for ERR899427.fastq.gz
# Approx 55% complete for ERR899429.fastq.gz
# Approx 60% complete for ERR899428.fastq.gz
# Approx 55% complete for ERR899430.fastq.gz
# Approx 55% complete for ERR899426.fastq.gz
# Approx 55% complete for ERR899431.fastq.gz
# Approx 50% complete for ERR899438.fastq.gz
# Approx 60% complete for ERR899432.fastq.gz
# Approx 60% complete for ERR899435.fastq.gz
# Approx 55% complete for ERR899424.fastq.gz
# Approx 60% complete for ERR899434.fastq.gz
# Approx 55% complete for ERR899433.fastq.gz
# Approx 60% complete for ERR899421.fastq.gz
# Approx 60% complete for ERR899436.fastq.gz
# Approx 60% complete for ERR899423.fastq.gz
# Approx 60% complete for ERR899437.fastq.gz
# Approx 60% complete for ERR899422.fastq.gz
# Approx 65% complete for ERR899427.fastq.gz
# Approx 55% complete for ERR899425.fastq.gz
# Approx 65% complete for ERR899428.fastq.gz
# Approx 60% complete for ERR899429.fastq.gz
# Approx 60% complete for ERR899430.fastq.gz
# Approx 60% complete for ERR899426.fastq.gz
# Approx 60% complete for ERR899431.fastq.gz
# Approx 65% complete for ERR899432.fastq.gz
# Approx 65% complete for ERR899435.fastq.gz
# Approx 55% complete for ERR899438.fastq.gz
# Approx 65% complete for ERR899434.fastq.gz
# Approx 65% complete for ERR899421.fastq.gz
# Approx 60% complete for ERR899424.fastq.gz
# Approx 65% complete for ERR899436.fastq.gz
# Approx 60% complete for ERR899433.fastq.gz
# Approx 65% complete for ERR899423.fastq.gz
# Approx 65% complete for ERR899437.fastq.gz
# Approx 65% complete for ERR899422.fastq.gz
# Approx 70% complete for ERR899427.fastq.gz
# Approx 70% complete for ERR899428.fastq.gz
# Approx 60% complete for ERR899425.fastq.gz
# Approx 65% complete for ERR899429.fastq.gz
# Approx 65% complete for ERR899430.fastq.gz
# Approx 70% complete for ERR899432.fastq.gz
# Approx 70% complete for ERR899435.fastq.gz
# Approx 65% complete for ERR899426.fastq.gz
# Approx 65% complete for ERR899431.fastq.gz
# Approx 70% complete for ERR899421.fastq.gz
# Approx 70% complete for ERR899434.fastq.gz
# Approx 70% complete for ERR899436.fastq.gz
# Approx 60% complete for ERR899438.fastq.gz
# Approx 65% complete for ERR899424.fastq.gz
# Approx 70% complete for ERR899423.fastq.gz
# Approx 70% complete for ERR899437.fastq.gz
# Approx 65% complete for ERR899433.fastq.gz
# Approx 75% complete for ERR899427.fastq.gz
# Approx 70% complete for ERR899422.fastq.gz
# Approx 75% complete for ERR899428.fastq.gz
# Approx 70% complete for ERR899429.fastq.gz
# Approx 65% complete for ERR899425.fastq.gz
# Approx 70% complete for ERR899430.fastq.gz
# Approx 75% complete for ERR899435.fastq.gz
# Approx 75% complete for ERR899432.fastq.gz
# Approx 70% complete for ERR899426.fastq.gz
# Approx 70% complete for ERR899431.fastq.gz
# Approx 75% complete for ERR899421.fastq.gz
# Approx 75% complete for ERR899434.fastq.gz
# Approx 75% complete for ERR899436.fastq.gz
# Approx 70% complete for ERR899424.fastq.gz
# Approx 75% complete for ERR899423.fastq.gz
# Approx 80% complete for ERR899427.fastq.gz
# Approx 75% complete for ERR899437.fastq.gz
# Approx 65% complete for ERR899438.fastq.gz
# Approx 75% complete for ERR899422.fastq.gz
# Approx 80% complete for ERR899428.fastq.gz
# Approx 70% complete for ERR899433.fastq.gz
# Approx 75% complete for ERR899429.fastq.gz
# Approx 70% complete for ERR899425.fastq.gz
# Approx 80% complete for ERR899435.fastq.gz
# Approx 80% complete for ERR899432.fastq.gz
# Approx 75% complete for ERR899430.fastq.gz
# Approx 75% complete for ERR899426.fastq.gz
# Approx 75% complete for ERR899431.fastq.gz
# Approx 80% complete for ERR899421.fastq.gz
# Approx 80% complete for ERR899434.fastq.gz
# Approx 80% complete for ERR899436.fastq.gz
# Approx 80% complete for ERR899423.fastq.gz
# Approx 85% complete for ERR899427.fastq.gz
# Approx 75% complete for ERR899424.fastq.gz
# Approx 80% complete for ERR899437.fastq.gz
# Approx 85% complete for ERR899428.fastq.gz
# Approx 80% complete for ERR899422.fastq.gz
# Approx 70% complete for ERR899438.fastq.gz
# Approx 75% complete for ERR899433.fastq.gz
# Approx 80% complete for ERR899429.fastq.gz
# Approx 85% complete for ERR899435.fastq.gz
# Approx 85% complete for ERR899432.fastq.gz
# Approx 75% complete for ERR899425.fastq.gz
# Approx 80% complete for ERR899430.fastq.gz
# Approx 85% complete for ERR899421.fastq.gz
# Approx 85% complete for ERR899434.fastq.gz
# Approx 80% complete for ERR899426.fastq.gz
# Approx 80% complete for ERR899431.fastq.gz
# Approx 85% complete for ERR899436.fastq.gz
# Approx 90% complete for ERR899427.fastq.gz
# Approx 85% complete for ERR899423.fastq.gz
# Approx 80% complete for ERR899424.fastq.gz
# Approx 90% complete for ERR899428.fastq.gz
# Approx 85% complete for ERR899437.fastq.gz
# Approx 85% complete for ERR899422.fastq.gz
# Approx 80% complete for ERR899433.fastq.gz
# Approx 75% complete for ERR899438.fastq.gz
# Approx 90% complete for ERR899435.fastq.gz
# Approx 85% complete for ERR899429.fastq.gz
# Approx 90% complete for ERR899432.fastq.gz
# Approx 90% complete for ERR899421.fastq.gz
# Approx 85% complete for ERR899430.fastq.gz
# Approx 90% complete for ERR899434.fastq.gz
# Approx 80% complete for ERR899425.fastq.gz
# Approx 90% complete for ERR899436.fastq.gz
# Approx 85% complete for ERR899426.fastq.gz
# Approx 95% complete for ERR899427.fastq.gz
# Approx 85% complete for ERR899431.fastq.gz
# Approx 90% complete for ERR899423.fastq.gz
# Approx 95% complete for ERR899428.fastq.gz
# Approx 85% complete for ERR899424.fastq.gz
# Approx 90% complete for ERR899437.fastq.gz
# Approx 90% complete for ERR899422.fastq.gz
# Approx 85% complete for ERR899433.fastq.gz
# Approx 80% complete for ERR899438.fastq.gz
# Approx 95% complete for ERR899435.fastq.gz
# Approx 95% complete for ERR899432.fastq.gz
# Approx 90% complete for ERR899429.fastq.gz
# Approx 95% complete for ERR899421.fastq.gz
# Approx 95% complete for ERR899434.fastq.gz
# Analysis complete for ERR899427.fastq.gz
# Approx 90% complete for ERR899430.fastq.gz
# Approx 95% complete for ERR899436.fastq.gz
# Approx 90% complete for ERR899426.fastq.gz
# Approx 85% complete for ERR899425.fastq.gz
# Approx 90% complete for ERR899431.fastq.gz
# Analysis complete for ERR899428.fastq.gz
# Approx 95% complete for ERR899423.fastq.gz
# Approx 95% complete for ERR899437.fastq.gz
# Approx 90% complete for ERR899424.fastq.gz
# Approx 95% complete for ERR899422.fastq.gz
# Approx 90% complete for ERR899433.fastq.gz
# Analysis complete for ERR899435.fastq.gz
# Analysis complete for ERR899432.fastq.gz
# Approx 85% complete for ERR899438.fastq.gz
# Approx 95% complete for ERR899429.fastq.gz
# Analysis complete for ERR899421.fastq.gz
# Analysis complete for ERR899434.fastq.gz
# Analysis complete for ERR899436.fastq.gz
# Approx 95% complete for ERR899430.fastq.gz
# Analysis complete for ERR899423.fastq.gz
# Approx 95% complete for ERR899431.fastq.gz
# Approx 95% complete for ERR899426.fastq.gz
# Approx 90% complete for ERR899425.fastq.gz
# Analysis complete for ERR899437.fastq.gz
# Approx 95% complete for ERR899424.fastq.gz
# Analysis complete for ERR899422.fastq.gz
# Approx 95% complete for ERR899433.fastq.gz
# Analysis complete for ERR899429.fastq.gz
# Approx 90% complete for ERR899438.fastq.gz
# Analysis complete for ERR899430.fastq.gz
# Analysis complete for ERR899431.fastq.gz
# Analysis complete for ERR899426.fastq.gz
# Approx 95% complete for ERR899425.fastq.gz
# Analysis complete for ERR899424.fastq.gz
# Analysis complete for ERR899433.fastq.gz
# Approx 95% complete for ERR899438.fastq.gz
# Analysis complete for ERR899425.fastq.gz
# Analysis complete for ERR899438.fastq.gz

# %%
old_cmd = '''
#fastqc of trimmed_sequencing reads

#load fastqc
module load fastqc

fqs=""

for basename in $(ls $FASTQS | cut -f1 -d '.'); do
    #basename=$(echo $fq | cut -f1 -d '.')
    fqd=$TFASTQS
    fq1=".fastq.gz"
    fq1=$fqd/$basename$fq1
    fqs="$fqs $fq1"
    
done

for basename in $(ls $P$FASTQS | cut -f1 -d '_' | sort | uniq); do
    echo $basename
    fqd=$PTFASTQS
    fq1="_trimmed_1.fastq.gz"
    fq2="_trimmed_2.fastq.gz"
    fq1=$fqd/$basename$fq1
    fq2=$fqd/$basename$fq2
    fqs="$fqs $fq1 $fq2"
done

echo "Performing FastQC for $fqs"
fastqc --threads $MAXCORES $fqs -o $TFASTQCOUT
'''

#out=run_cmd(cmd)

tfastq_files = glob.glob(TFASTQS+"/*.fq.gz") 

cmds = []
for tfastq_file in tfastq_files:
    cmds.append(ENVCMD + " && " +
                "module load fastqc && " +
                "fastqc " + 
                tfastq_file +
                " -o " + TFASTQCOUT)

pool = Pool(processes=MAXCORES)
results = pool.map_async(run_cmd, cmds)
pool.close()
pool.join()
pool.terminate()
# Out:
# Started analysis of ERR899435_trimmed.fq.gz
# Started analysis of ERR899425_trimmed.fq.gz
# Started analysis of ERR899431_trimmed.fq.gz
# Started analysis of ERR899434_trimmed.fq.gz
# Started analysis of ERR899432_trimmed.fq.gz
# Started analysis of ERR899423_trimmed.fq.gz
# Started analysis of ERR899429_trimmed.fq.gz
# Started analysis of ERR899424_trimmed.fq.gz
# Started analysis of ERR899428_trimmed.fq.gz
# Started analysis of ERR899436_trimmed.fq.gz
# Started analysis of ERR899422_trimmed.fq.gz
# Started analysis of ERR899427_trimmed.fq.gz
# Started analysis of ERR899421_trimmed.fq.gz
# Started analysis of ERR899437_trimmed.fq.gz
# Started analysis of ERR899433_trimmed.fq.gz
# Started analysis of ERR899430_trimmed.fq.gz
# Started analysis of ERR899438_trimmed.fq.gz
# Started analysis of ERR899426_trimmed.fq.gz
# Approx 5% complete for ERR899427_trimmed.fq.gz
# Approx 5% complete for ERR899428_trimmed.fq.gz
# Approx 5% complete for ERR899435_trimmed.fq.gz
# Approx 5% complete for ERR899421_trimmed.fq.gz
# Approx 5% complete for ERR899432_trimmed.fq.gz
# Approx 5% complete for ERR899437_trimmed.fq.gz
# Approx 5% complete for ERR899434_trimmed.fq.gz
# Approx 5% complete for ERR899436_trimmed.fq.gz
# Approx 5% complete for ERR899423_trimmed.fq.gz
# Approx 5% complete for ERR899424_trimmed.fq.gz
# Approx 5% complete for ERR899422_trimmed.fq.gz
# Approx 5% complete for ERR899429_trimmed.fq.gz
# Approx 5% complete for ERR899431_trimmed.fq.gz
# Approx 5% complete for ERR899433_trimmed.fq.gz
# Approx 5% complete for ERR899426_trimmed.fq.gz
# Approx 5% complete for ERR899430_trimmed.fq.gz
# Approx 5% complete for ERR899425_trimmed.fq.gz
# Approx 5% complete for ERR899438_trimmed.fq.gz
# Approx 10% complete for ERR899427_trimmed.fq.gz
# Approx 10% complete for ERR899428_trimmed.fq.gz
# Approx 10% complete for ERR899435_trimmed.fq.gz
# Approx 10% complete for ERR899421_trimmed.fq.gz
# Approx 10% complete for ERR899432_trimmed.fq.gz
# Approx 10% complete for ERR899436_trimmed.fq.gz
# Approx 10% complete for ERR899437_trimmed.fq.gz
# Approx 10% complete for ERR899434_trimmed.fq.gz
# Approx 10% complete for ERR899423_trimmed.fq.gz
# Approx 10% complete for ERR899424_trimmed.fq.gz
# Approx 10% complete for ERR899422_trimmed.fq.gz
# Approx 10% complete for ERR899429_trimmed.fq.gz
# Approx 10% complete for ERR899430_trimmed.fq.gz
# Approx 10% complete for ERR899431_trimmed.fq.gz
# Approx 10% complete for ERR899426_trimmed.fq.gz
# Approx 10% complete for ERR899433_trimmed.fq.gz
# Approx 10% complete for ERR899425_trimmed.fq.gz
# Approx 10% complete for ERR899438_trimmed.fq.gz
# Approx 15% complete for ERR899427_trimmed.fq.gz
# Approx 15% complete for ERR899428_trimmed.fq.gz
# Approx 15% complete for ERR899435_trimmed.fq.gz
# Approx 15% complete for ERR899421_trimmed.fq.gz
# Approx 15% complete for ERR899432_trimmed.fq.gz
# Approx 15% complete for ERR899436_trimmed.fq.gz
# Approx 15% complete for ERR899434_trimmed.fq.gz
# Approx 15% complete for ERR899423_trimmed.fq.gz
# Approx 15% complete for ERR899437_trimmed.fq.gz
# Approx 15% complete for ERR899424_trimmed.fq.gz
# Approx 15% complete for ERR899422_trimmed.fq.gz
# Approx 15% complete for ERR899429_trimmed.fq.gz
# Approx 15% complete for ERR899426_trimmed.fq.gz
# Approx 15% complete for ERR899430_trimmed.fq.gz
# Approx 15% complete for ERR899431_trimmed.fq.gz
# Approx 15% complete for ERR899433_trimmed.fq.gz
# Approx 15% complete for ERR899425_trimmed.fq.gz
# Approx 15% complete for ERR899438_trimmed.fq.gz
# Approx 20% complete for ERR899427_trimmed.fq.gz
# Approx 20% complete for ERR899428_trimmed.fq.gz
# Approx 20% complete for ERR899435_trimmed.fq.gz
# Approx 20% complete for ERR899421_trimmed.fq.gz
# Approx 20% complete for ERR899432_trimmed.fq.gz
# Approx 20% complete for ERR899436_trimmed.fq.gz
# Approx 20% complete for ERR899434_trimmed.fq.gz
# Approx 20% complete for ERR899423_trimmed.fq.gz
# Approx 20% complete for ERR899437_trimmed.fq.gz
# Approx 20% complete for ERR899424_trimmed.fq.gz
# Approx 20% complete for ERR899422_trimmed.fq.gz
# Approx 20% complete for ERR899429_trimmed.fq.gz
# Approx 20% complete for ERR899426_trimmed.fq.gz
# Approx 20% complete for ERR899430_trimmed.fq.gz
# Approx 20% complete for ERR899431_trimmed.fq.gz
# Approx 20% complete for ERR899433_trimmed.fq.gz
# Approx 20% complete for ERR899425_trimmed.fq.gz
# Approx 25% complete for ERR899427_trimmed.fq.gz
# Approx 20% complete for ERR899438_trimmed.fq.gz
# Approx 25% complete for ERR899428_trimmed.fq.gz
# Approx 25% complete for ERR899435_trimmed.fq.gz
# Approx 25% complete for ERR899421_trimmed.fq.gz
# Approx 25% complete for ERR899432_trimmed.fq.gz
# Approx 25% complete for ERR899436_trimmed.fq.gz
# Approx 25% complete for ERR899423_trimmed.fq.gz
# Approx 25% complete for ERR899434_trimmed.fq.gz
# Approx 25% complete for ERR899424_trimmed.fq.gz
# Approx 25% complete for ERR899437_trimmed.fq.gz
# Approx 25% complete for ERR899422_trimmed.fq.gz
# Approx 25% complete for ERR899430_trimmed.fq.gz
# Approx 25% complete for ERR899431_trimmed.fq.gz
# Approx 25% complete for ERR899429_trimmed.fq.gz
# Approx 25% complete for ERR899426_trimmed.fq.gz
# Approx 25% complete for ERR899433_trimmed.fq.gz
# Approx 25% complete for ERR899425_trimmed.fq.gz
# Approx 30% complete for ERR899427_trimmed.fq.gz
# Approx 30% complete for ERR899428_trimmed.fq.gz
# Approx 30% complete for ERR899435_trimmed.fq.gz
# Approx 25% complete for ERR899438_trimmed.fq.gz
# Approx 30% complete for ERR899421_trimmed.fq.gz
# Approx 30% complete for ERR899432_trimmed.fq.gz
# Approx 30% complete for ERR899436_trimmed.fq.gz
# Approx 30% complete for ERR899434_trimmed.fq.gz
# Approx 30% complete for ERR899423_trimmed.fq.gz
# Approx 30% complete for ERR899437_trimmed.fq.gz
# Approx 30% complete for ERR899424_trimmed.fq.gz
# Approx 30% complete for ERR899422_trimmed.fq.gz
# Approx 30% complete for ERR899430_trimmed.fq.gz
# Approx 30% complete for ERR899426_trimmed.fq.gz
# Approx 30% complete for ERR899431_trimmed.fq.gz
# Approx 30% complete for ERR899429_trimmed.fq.gz
# Approx 35% complete for ERR899427_trimmed.fq.gz
# Approx 30% complete for ERR899433_trimmed.fq.gz
# Approx 35% complete for ERR899428_trimmed.fq.gz
# Approx 30% complete for ERR899425_trimmed.fq.gz
# Approx 35% complete for ERR899435_trimmed.fq.gz
# Approx 35% complete for ERR899421_trimmed.fq.gz
# Approx 35% complete for ERR899432_trimmed.fq.gz
# Approx 35% complete for ERR899436_trimmed.fq.gz
# Approx 35% complete for ERR899434_trimmed.fq.gz
# Approx 35% complete for ERR899423_trimmed.fq.gz
# Approx 30% complete for ERR899438_trimmed.fq.gz
# Approx 35% complete for ERR899437_trimmed.fq.gz
# Approx 35% complete for ERR899424_trimmed.fq.gz
# Approx 35% complete for ERR899422_trimmed.fq.gz
# Approx 35% complete for ERR899430_trimmed.fq.gz
# Approx 35% complete for ERR899426_trimmed.fq.gz
# Approx 35% complete for ERR899431_trimmed.fq.gz
# Approx 35% complete for ERR899429_trimmed.fq.gz
# Approx 40% complete for ERR899427_trimmed.fq.gz
# Approx 40% complete for ERR899428_trimmed.fq.gz
# Approx 35% complete for ERR899433_trimmed.fq.gz
# Approx 40% complete for ERR899435_trimmed.fq.gz
# Approx 35% complete for ERR899425_trimmed.fq.gz
# Approx 40% complete for ERR899421_trimmed.fq.gz
# Approx 40% complete for ERR899432_trimmed.fq.gz
# Approx 40% complete for ERR899436_trimmed.fq.gz
# Approx 40% complete for ERR899434_trimmed.fq.gz
# Approx 40% complete for ERR899423_trimmed.fq.gz
# Approx 40% complete for ERR899437_trimmed.fq.gz
# Approx 40% complete for ERR899424_trimmed.fq.gz
# Approx 40% complete for ERR899422_trimmed.fq.gz
# Approx 35% complete for ERR899438_trimmed.fq.gz
# Approx 40% complete for ERR899430_trimmed.fq.gz
# Approx 45% complete for ERR899427_trimmed.fq.gz
# Approx 40% complete for ERR899426_trimmed.fq.gz
# Approx 40% complete for ERR899431_trimmed.fq.gz
# Approx 40% complete for ERR899429_trimmed.fq.gz
# Approx 45% complete for ERR899428_trimmed.fq.gz
# Approx 40% complete for ERR899433_trimmed.fq.gz
# Approx 45% complete for ERR899435_trimmed.fq.gz
# Approx 45% complete for ERR899421_trimmed.fq.gz
# Approx 45% complete for ERR899432_trimmed.fq.gz
# Approx 40% complete for ERR899425_trimmed.fq.gz
# Approx 45% complete for ERR899436_trimmed.fq.gz
# Approx 45% complete for ERR899434_trimmed.fq.gz
# Approx 45% complete for ERR899423_trimmed.fq.gz
# Approx 45% complete for ERR899437_trimmed.fq.gz
# Approx 45% complete for ERR899424_trimmed.fq.gz
# Approx 45% complete for ERR899422_trimmed.fq.gz
# Approx 50% complete for ERR899427_trimmed.fq.gz
# Approx 40% complete for ERR899438_trimmed.fq.gz
# Approx 45% complete for ERR899430_trimmed.fq.gz
# Approx 45% complete for ERR899431_trimmed.fq.gz
# Approx 50% complete for ERR899428_trimmed.fq.gz
# Approx 45% complete for ERR899426_trimmed.fq.gz
# Approx 45% complete for ERR899429_trimmed.fq.gz
# Approx 45% complete for ERR899433_trimmed.fq.gz
# Approx 50% complete for ERR899435_trimmed.fq.gz
# Approx 50% complete for ERR899421_trimmed.fq.gz
# Approx 50% complete for ERR899432_trimmed.fq.gz
# Approx 50% complete for ERR899436_trimmed.fq.gz
# Approx 50% complete for ERR899434_trimmed.fq.gz
# Approx 50% complete for ERR899423_trimmed.fq.gz
# Approx 45% complete for ERR899425_trimmed.fq.gz
# Approx 50% complete for ERR899437_trimmed.fq.gz
# Approx 50% complete for ERR899424_trimmed.fq.gz
# Approx 50% complete for ERR899422_trimmed.fq.gz
# Approx 55% complete for ERR899427_trimmed.fq.gz
# Approx 55% complete for ERR899428_trimmed.fq.gz
# Approx 50% complete for ERR899430_trimmed.fq.gz
# Approx 45% complete for ERR899438_trimmed.fq.gz
# Approx 50% complete for ERR899431_trimmed.fq.gz
# Approx 50% complete for ERR899426_trimmed.fq.gz
# Approx 50% complete for ERR899429_trimmed.fq.gz
# Approx 55% complete for ERR899435_trimmed.fq.gz
# Approx 50% complete for ERR899433_trimmed.fq.gz
# Approx 55% complete for ERR899421_trimmed.fq.gz
# Approx 55% complete for ERR899432_trimmed.fq.gz
# Approx 55% complete for ERR899436_trimmed.fq.gz
# Approx 55% complete for ERR899434_trimmed.fq.gz
# Approx 55% complete for ERR899423_trimmed.fq.gz
# Approx 55% complete for ERR899437_trimmed.fq.gz
# Approx 55% complete for ERR899424_trimmed.fq.gz
# Approx 60% complete for ERR899427_trimmed.fq.gz
# Approx 50% complete for ERR899425_trimmed.fq.gz
# Approx 55% complete for ERR899422_trimmed.fq.gz
# Approx 60% complete for ERR899428_trimmed.fq.gz
# Approx 55% complete for ERR899430_trimmed.fq.gz
# Approx 55% complete for ERR899431_trimmed.fq.gz
# Approx 55% complete for ERR899426_trimmed.fq.gz
# Approx 55% complete for ERR899429_trimmed.fq.gz
# Approx 50% complete for ERR899438_trimmed.fq.gz
# Approx 60% complete for ERR899435_trimmed.fq.gz
# Approx 60% complete for ERR899421_trimmed.fq.gz
# Approx 60% complete for ERR899432_trimmed.fq.gz
# Approx 60% complete for ERR899436_trimmed.fq.gz
# Approx 55% complete for ERR899433_trimmed.fq.gz
# Approx 60% complete for ERR899434_trimmed.fq.gz
# Approx 60% complete for ERR899423_trimmed.fq.gz
# Approx 65% complete for ERR899427_trimmed.fq.gz
# Approx 60% complete for ERR899424_trimmed.fq.gz
# Approx 60% complete for ERR899437_trimmed.fq.gz
# Approx 60% complete for ERR899422_trimmed.fq.gz
# Approx 55% complete for ERR899425_trimmed.fq.gz
# Approx 65% complete for ERR899428_trimmed.fq.gz
# Approx 60% complete for ERR899430_trimmed.fq.gz
# Approx 60% complete for ERR899426_trimmed.fq.gz
# Approx 60% complete for ERR899431_trimmed.fq.gz
# Approx 60% complete for ERR899429_trimmed.fq.gz
# Approx 65% complete for ERR899435_trimmed.fq.gz
# Approx 65% complete for ERR899421_trimmed.fq.gz
# Approx 55% complete for ERR899438_trimmed.fq.gz
# Approx 65% complete for ERR899436_trimmed.fq.gz
# Approx 65% complete for ERR899432_trimmed.fq.gz
# Approx 60% complete for ERR899433_trimmed.fq.gz
# Approx 65% complete for ERR899434_trimmed.fq.gz
# Approx 70% complete for ERR899427_trimmed.fq.gz
# Approx 65% complete for ERR899423_trimmed.fq.gz
# Approx 65% complete for ERR899437_trimmed.fq.gz
# Approx 65% complete for ERR899424_trimmed.fq.gz
# Approx 70% complete for ERR899428_trimmed.fq.gz
# Approx 65% complete for ERR899422_trimmed.fq.gz
# Approx 60% complete for ERR899425_trimmed.fq.gz
# Approx 65% complete for ERR899430_trimmed.fq.gz
# Approx 65% complete for ERR899426_trimmed.fq.gz
# Approx 70% complete for ERR899435_trimmed.fq.gz
# Approx 65% complete for ERR899431_trimmed.fq.gz
# Approx 65% complete for ERR899429_trimmed.fq.gz
# Approx 70% complete for ERR899421_trimmed.fq.gz
# Approx 70% complete for ERR899432_trimmed.fq.gz
# Approx 70% complete for ERR899436_trimmed.fq.gz
# Approx 60% complete for ERR899438_trimmed.fq.gz
# Approx 75% complete for ERR899427_trimmed.fq.gz
# Approx 70% complete for ERR899434_trimmed.fq.gz
# Approx 65% complete for ERR899433_trimmed.fq.gz
# Approx 70% complete for ERR899423_trimmed.fq.gz
# Approx 70% complete for ERR899437_trimmed.fq.gz
# Approx 70% complete for ERR899424_trimmed.fq.gz
# Approx 75% complete for ERR899428_trimmed.fq.gz
# Approx 70% complete for ERR899422_trimmed.fq.gz
# Approx 70% complete for ERR899430_trimmed.fq.gz
# Approx 65% complete for ERR899425_trimmed.fq.gz
# Approx 75% complete for ERR899435_trimmed.fq.gz
# Approx 70% complete for ERR899426_trimmed.fq.gz
# Approx 70% complete for ERR899431_trimmed.fq.gz
# Approx 70% complete for ERR899429_trimmed.fq.gz
# Approx 75% complete for ERR899421_trimmed.fq.gz
# Approx 80% complete for ERR899427_trimmed.fq.gz
# Approx 75% complete for ERR899436_trimmed.fq.gz
# Approx 75% complete for ERR899432_trimmed.fq.gz
# Approx 75% complete for ERR899434_trimmed.fq.gz
# Approx 65% complete for ERR899438_trimmed.fq.gz
# Approx 75% complete for ERR899423_trimmed.fq.gz
# Approx 70% complete for ERR899433_trimmed.fq.gz
# Approx 75% complete for ERR899437_trimmed.fq.gz
# Approx 75% complete for ERR899424_trimmed.fq.gz
# Approx 80% complete for ERR899428_trimmed.fq.gz
# Approx 75% complete for ERR899422_trimmed.fq.gz
# Approx 75% complete for ERR899430_trimmed.fq.gz
# Approx 80% complete for ERR899435_trimmed.fq.gz
# Approx 70% complete for ERR899425_trimmed.fq.gz
# Approx 75% complete for ERR899426_trimmed.fq.gz
# Approx 80% complete for ERR899421_trimmed.fq.gz
# Approx 85% complete for ERR899427_trimmed.fq.gz
# Approx 75% complete for ERR899431_trimmed.fq.gz
# Approx 75% complete for ERR899429_trimmed.fq.gz
# Approx 80% complete for ERR899436_trimmed.fq.gz
# Approx 80% complete for ERR899432_trimmed.fq.gz
# Approx 80% complete for ERR899434_trimmed.fq.gz
# Approx 80% complete for ERR899423_trimmed.fq.gz
# Approx 85% complete for ERR899428_trimmed.fq.gz
# Approx 80% complete for ERR899424_trimmed.fq.gz
# Approx 80% complete for ERR899437_trimmed.fq.gz
# Approx 75% complete for ERR899433_trimmed.fq.gz
# Approx 70% complete for ERR899438_trimmed.fq.gz
# Approx 80% complete for ERR899422_trimmed.fq.gz
# Approx 80% complete for ERR899430_trimmed.fq.gz
# Approx 85% complete for ERR899435_trimmed.fq.gz
# Approx 90% complete for ERR899427_trimmed.fq.gz
# Approx 85% complete for ERR899421_trimmed.fq.gz
# Approx 80% complete for ERR899426_trimmed.fq.gz
# Approx 75% complete for ERR899425_trimmed.fq.gz
# Approx 85% complete for ERR899436_trimmed.fq.gz
# Approx 85% complete for ERR899432_trimmed.fq.gz
# Approx 80% complete for ERR899429_trimmed.fq.gz
# Approx 80% complete for ERR899431_trimmed.fq.gz
# Approx 85% complete for ERR899434_trimmed.fq.gz
# Approx 85% complete for ERR899423_trimmed.fq.gz
# Approx 90% complete for ERR899428_trimmed.fq.gz
# Approx 85% complete for ERR899424_trimmed.fq.gz
# Approx 85% complete for ERR899437_trimmed.fq.gz
# Approx 80% complete for ERR899433_trimmed.fq.gz
# Approx 85% complete for ERR899422_trimmed.fq.gz
# Approx 75% complete for ERR899438_trimmed.fq.gz
# Approx 90% complete for ERR899435_trimmed.fq.gz
# Approx 85% complete for ERR899430_trimmed.fq.gz
# Approx 95% complete for ERR899427_trimmed.fq.gz
# Approx 90% complete for ERR899421_trimmed.fq.gz
# Approx 85% complete for ERR899426_trimmed.fq.gz
# Approx 90% complete for ERR899436_trimmed.fq.gz
# Approx 90% complete for ERR899432_trimmed.fq.gz
# Approx 85% complete for ERR899429_trimmed.fq.gz
# Approx 90% complete for ERR899434_trimmed.fq.gz
# Approx 80% complete for ERR899425_trimmed.fq.gz
# Approx 85% complete for ERR899431_trimmed.fq.gz
# Approx 95% complete for ERR899428_trimmed.fq.gz
# Approx 90% complete for ERR899423_trimmed.fq.gz
# Approx 90% complete for ERR899424_trimmed.fq.gz
# Approx 90% complete for ERR899437_trimmed.fq.gz
# Approx 85% complete for ERR899433_trimmed.fq.gz
# Approx 90% complete for ERR899422_trimmed.fq.gz
# Approx 80% complete for ERR899438_trimmed.fq.gz
# Approx 95% complete for ERR899435_trimmed.fq.gz
# Analysis complete for ERR899427_trimmed.fq.gz
# Approx 90% complete for ERR899430_trimmed.fq.gz
# Approx 95% complete for ERR899421_trimmed.fq.gz
# Approx 95% complete for ERR899436_trimmed.fq.gz
# Approx 95% complete for ERR899432_trimmed.fq.gz
# Approx 90% complete for ERR899426_trimmed.fq.gz
# Approx 95% complete for ERR899434_trimmed.fq.gz
# Approx 90% complete for ERR899429_trimmed.fq.gz
# Approx 90% complete for ERR899431_trimmed.fq.gz
# Analysis complete for ERR899428_trimmed.fq.gz
# Approx 85% complete for ERR899425_trimmed.fq.gz
# Approx 95% complete for ERR899423_trimmed.fq.gz
# Approx 95% complete for ERR899424_trimmed.fq.gz
# Approx 95% complete for ERR899437_trimmed.fq.gz
# Approx 90% complete for ERR899433_trimmed.fq.gz
# Approx 95% complete for ERR899422_trimmed.fq.gz
# Analysis complete for ERR899435_trimmed.fq.gz
# Approx 95% complete for ERR899430_trimmed.fq.gz
# Approx 85% complete for ERR899438_trimmed.fq.gz
# Analysis complete for ERR899421_trimmed.fq.gz
# Analysis complete for ERR899432_trimmed.fq.gz
# Analysis complete for ERR899436_trimmed.fq.gz
# Approx 95% complete for ERR899426_trimmed.fq.gz
# Analysis complete for ERR899434_trimmed.fq.gz
# Approx 95% complete for ERR899431_trimmed.fq.gz
# Approx 95% complete for ERR899429_trimmed.fq.gz
# Analysis complete for ERR899423_trimmed.fq.gz
# Approx 90% complete for ERR899425_trimmed.fq.gz
# Analysis complete for ERR899424_trimmed.fq.gz
# Analysis complete for ERR899437_trimmed.fq.gz
# Analysis complete for ERR899422_trimmed.fq.gz
# Approx 95% complete for ERR899433_trimmed.fq.gz
# Analysis complete for ERR899430_trimmed.fq.gz
# Approx 90% complete for ERR899438_trimmed.fq.gz
# Analysis complete for ERR899426_trimmed.fq.gz
# Analysis complete for ERR899429_trimmed.fq.gz
# Analysis complete for ERR899431_trimmed.fq.gz
# Approx 95% complete for ERR899425_trimmed.fq.gz
# Analysis complete for ERR899433_trimmed.fq.gz
# Approx 95% complete for ERR899438_trimmed.fq.gz
# Analysis complete for ERR899425_trimmed.fq.gz
# Analysis complete for ERR899438_trimmed.fq.gz

# %%
cmd='''
#module load star

for basename in $(ls $FASTQC | cut -f1 -d '.'); do
    fqd=$TFASTQS
    fq1=".fastq.gz"
    fq1=$fqd/$basename$fq1
    
    echo "Aligning reads from $basename to the reference genome"
    $BINDIR/STAR \
        --genomeDir $STARGENOMEDIR \
        --sjdbGTFfile $GENEANNOTATIONDIR/genes.gtf \
        --runThreadN $MAXCORES \
        --outSAMstrandField intronMotif \
        --outFilterIntronMotifs RemoveNoncanonical \
        --outFileNamePrefix $STARDIR/$basename  \
        --readFilesIn $fq1 \
        --readFilesCommand zcat \
        --outSAMtype BAM Unsorted \
        --outReadsUnmapped Fastx \
        --outSAMmode Full
done


for basename in $(ls $PFASTQC | cut -f1 -d '_' | sort | uniq); do
    fqd=$TPFASTQS
    fq1="trimmed_1.fastq.gz"
    fq2="trimmed_2.fastq.gz"
    fq1=$fqd/$basename$fq1
    fq2=$fqd/$basename$fq2
    fqs="$fqs $fq1 $fq2"
    
    
    echo "Aligning reads from $basename to the reference genome"
    $BINDIR/STAR \
        --genomeDir $STARGENOMEDIR \
        --sjdbGTFfile $GENEANNOTATIONDIR/genes.gtf \
        --runThreadN $MAXCORES \
        --outSAMstrandField intronMotif \
        --outFilterIntronMotifs RemoveNoncanonical \
        --outFileNamePrefix $STARDIR/$basename \
        --readFilesIn $fq1 $fq2 \
        --readFilesCommand zcat \
        --outSAMtype BAM Unsorted \
        --outReadsUnmapped Fastx \
        --outSAMmode Full
done
'''
#out=run_cmd(cmd)
# Out:
# Aligning reads from ERR899421 to the reference genome
# Jan 19 12:19:38 ..... started STAR run
# Jan 19 12:19:38 ..... loading genome
# Jan 19 12:19:52 ..... processing annotations GTF
# Jan 19 12:20:25 ..... inserting junctions into the genome indices
# Jan 19 12:21:33 ..... started mapping
# Jan 19 12:23:17 ..... finished successfully
# Aligning reads from ERR899422 to the reference genome
# Jan 19 12:23:43 ..... started STAR run
# Jan 19 12:23:44 ..... loading genome
# Jan 19 12:23:57 ..... processing annotations GTF
# Jan 19 12:24:06 ..... inserting junctions into the genome indices
# Jan 19 12:25:13 ..... started mapping
# Jan 19 12:26:56 ..... finished successfully
# Aligning reads from ERR899423 to the reference genome
# Jan 19 12:27:25 ..... started STAR run
# Jan 19 12:27:25 ..... loading genome
# Jan 19 12:27:38 ..... processing annotations GTF
# Jan 19 12:28:12 ..... inserting junctions into the genome indices
# Jan 19 12:29:19 ..... started mapping
# Jan 19 12:30:59 ..... finished successfully
# Aligning reads from ERR899424 to the reference genome
# Jan 19 12:31:29 ..... started STAR run
# Jan 19 12:31:29 ..... loading genome
# Jan 19 12:31:41 ..... processing annotations GTF
# Jan 19 12:31:50 ..... inserting junctions into the genome indices
# Jan 19 12:32:57 ..... started mapping
# Jan 19 12:34:39 ..... finished successfully
# Aligning reads from ERR899425 to the reference genome
# Jan 19 12:35:07 ..... started STAR run
# Jan 19 12:35:08 ..... loading genome
# Jan 19 12:35:21 ..... processing annotations GTF
# Jan 19 12:35:56 ..... inserting junctions into the genome indices
# Jan 19 12:37:02 ..... started mapping
# Jan 19 12:38:55 ..... finished successfully
# Aligning reads from ERR899426 to the reference genome
# Jan 19 12:39:24 ..... started STAR run
# Jan 19 12:39:24 ..... loading genome
# Jan 19 12:39:37 ..... processing annotations GTF
# Jan 19 12:39:45 ..... inserting junctions into the genome indices
# Jan 19 12:40:52 ..... started mapping
# Jan 19 12:42:41 ..... finished successfully
# Aligning reads from ERR899427 to the reference genome
# Jan 19 12:43:06 ..... started STAR run
# Jan 19 12:43:07 ..... loading genome
# Jan 19 12:43:19 ..... processing annotations GTF
# Jan 19 12:43:53 ..... inserting junctions into the genome indices
# Jan 19 12:45:01 ..... started mapping
# Jan 19 12:46:34 ..... finished successfully
# Aligning reads from ERR899428 to the reference genome
# Jan 19 12:47:00 ..... started STAR run
# Jan 19 12:47:00 ..... loading genome
# Jan 19 12:47:13 ..... processing annotations GTF
# Jan 19 12:47:22 ..... inserting junctions into the genome indices
# Jan 19 12:48:28 ..... started mapping
# Jan 19 12:50:09 ..... finished successfully
# Aligning reads from ERR899429 to the reference genome
# Jan 19 12:50:36 ..... started STAR run
# Jan 19 12:50:36 ..... loading genome
# Jan 19 12:50:50 ..... processing annotations GTF
# Jan 19 12:51:38 ..... inserting junctions into the genome indices
# Jan 19 12:52:44 ..... started mapping
# Jan 19 12:54:30 ..... finished successfully
# Aligning reads from ERR899430 to the reference genome
# Jan 19 12:55:05 ..... started STAR run
# Jan 19 12:55:05 ..... loading genome
# Jan 19 12:56:40 ..... processing annotations GTF
# Jan 19 12:56:50 ..... inserting junctions into the genome indices
# Jan 19 12:57:55 ..... started mapping
# Jan 19 12:59:42 ..... finished successfully
# Aligning reads from ERR899431 to the reference genome
# Jan 19 13:00:11 ..... started STAR run
# Jan 19 13:00:11 ..... loading genome
# Jan 19 13:00:25 ..... processing annotations GTF
# Jan 19 13:00:34 ..... inserting junctions into the genome indices
# Jan 19 13:01:40 ..... started mapping
# Jan 19 13:03:25 ..... finished successfully
# Aligning reads from ERR899432 to the reference genome
# Jan 19 13:03:55 ..... started STAR run
# Jan 19 13:03:55 ..... loading genome
# Jan 19 13:04:09 ..... processing annotations GTF
# Jan 19 13:04:19 ..... inserting junctions into the genome indices
# Jan 19 13:05:25 ..... started mapping
# Jan 19 13:07:08 ..... finished successfully
# Aligning reads from ERR899433 to the reference genome
# Jan 19 13:07:35 ..... started STAR run
# Jan 19 13:07:35 ..... loading genome
# Jan 19 13:08:00 ..... processing annotations GTF
# Jan 19 13:08:09 ..... inserting junctions into the genome indices
# Jan 19 13:09:14 ..... started mapping
# Jan 19 13:11:03 ..... finished successfully
# Aligning reads from ERR899434 to the reference genome
# Jan 19 13:11:32 ..... started STAR run
# Jan 19 13:11:32 ..... loading genome
# Jan 19 13:11:47 ..... processing annotations GTF
# Jan 19 13:11:56 ..... inserting junctions into the genome indices
# Jan 19 13:13:01 ..... started mapping
# Jan 19 13:14:43 ..... finished successfully
# Aligning reads from ERR899435 to the reference genome
# Jan 19 13:15:11 ..... started STAR run
# Jan 19 13:15:11 ..... loading genome
# Jan 19 13:15:26 ..... processing annotations GTF
# Jan 19 13:15:37 ..... inserting junctions into the genome indices
# Jan 19 13:16:42 ..... started mapping
# Jan 19 13:18:26 ..... finished successfully
# Aligning reads from ERR899436 to the reference genome
# Jan 19 13:18:53 ..... started STAR run
# Jan 19 13:18:53 ..... loading genome
# Jan 19 13:19:07 ..... processing annotations GTF
# Jan 19 13:19:16 ..... inserting junctions into the genome indices
# Jan 19 13:20:21 ..... started mapping
# Jan 19 13:22:04 ..... finished successfully
# Aligning reads from ERR899437 to the reference genome
# Jan 19 13:22:32 ..... started STAR run
# Jan 19 13:22:32 ..... loading genome
# Jan 19 13:22:46 ..... processing annotations GTF
# Jan 19 13:22:55 ..... inserting junctions into the genome indices
# Jan 19 13:24:01 ..... started mapping
# Jan 19 13:25:45 ..... finished successfully
# Aligning reads from ERR899438 to the reference genome
# Jan 19 13:26:13 ..... started STAR run
# Jan 19 13:26:13 ..... loading genome
# Jan 19 13:26:27 ..... processing annotations GTF
# Jan 19 13:26:37 ..... inserting junctions into the genome indices
# Jan 19 13:27:41 ..... started mapping
# Jan 19 13:29:38 ..... finished successfully

# %%
cmd='''
for basename in $(find star_output/ -name '*Aligned.out.bam' -exec basename {} \; | cut -f1 -d '.' ); do
    suffix=".out.bam"
    outname="$FCDIR/$basename.count.txt"
    bam="$STARDIR/$basename$suffix"    
    $BINDIR/featureCounts \
        -T $MAXCORES \
        -t exon \
        -g gene_id \
        -a  $GENEANNOTATIONDIR/genes.gtf \
        -o $outname \
        $bam 
done
'''
out=run_cmd(cmd)
# Out:
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v1.6.0
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           S ./star_output/ERR899421Aligned.out.bam         ||
# ||                                                                            ||
# ||             Output file : ./featureCount_output/ERR899421Aligned.count ... ||
# ||                 Summary : ./featureCount_output/ERR899421Aligned.count ... ||
# ||              Annotation : /fs/project/PAS1307/genomes/Mus_musculus/Ens ... ||
# ||      Dir for temp files : ./featureCount_output                            ||
# ||                                                                            ||
# ||                 Threads : 24                                               ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||         Strand specific : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file /fs/project/PAS1307/genomes/Mus_musculus/Ensembl/ ... ||
# ||    Features : 690647                                                       ||
# ||    Meta-features : 46078                                                   ||
# ||    Chromosomes/contigs : 73                                                ||
# ||                                                                            ||
# || Process BAM file ./star_output/ERR899421Aligned.out.bam...                 ||
# ||    Single-end reads are included.                                          ||
# ||    Assign reads to features...                                             ||
# ||    Total reads : 7101659                                                   ||
# ||    Successfully assigned reads : 4086182 (57.5%)                           ||
# ||    Running time : 0.32 minutes                                             ||
# ||                                                                            ||
# ||                         Read assignment finished.                          ||
# ||                                                                            ||
# || Summary of counting results can be found in file "./featureCount_output/E  ||
# || RR899421Aligned.count.txt.summary"                                         ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v1.6.0
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           S ./star_output/ERR899422Aligned.out.bam         ||
# ||                                                                            ||
# ||             Output file : ./featureCount_output/ERR899422Aligned.count ... ||
# ||                 Summary : ./featureCount_output/ERR899422Aligned.count ... ||
# ||              Annotation : /fs/project/PAS1307/genomes/Mus_musculus/Ens ... ||
# ||      Dir for temp files : ./featureCount_output                            ||
# ||                                                                            ||
# ||                 Threads : 24                                               ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||         Strand specific : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file /fs/project/PAS1307/genomes/Mus_musculus/Ensembl/ ... ||
# ||    Features : 690647                                                       ||
# ||    Meta-features : 46078                                                   ||
# ||    Chromosomes/contigs : 73                                                ||
# ||                                                                            ||
# || Process BAM file ./star_output/ERR899422Aligned.out.bam...                 ||
# ||    Single-end reads are included.                                          ||
# ||    Assign reads to features...                                             ||
# ||    Total reads : 8079369                                                   ||
# ||    Successfully assigned reads : 4246258 (52.6%)                           ||
# ||    Running time : 0.35 minutes                                             ||
# ||                                                                            ||
# ||                         Read assignment finished.                          ||
# ||                                                                            ||
# || Summary of counting results can be found in file "./featureCount_output/E  ||
# || RR899422Aligned.count.txt.summary"                                         ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v1.6.0
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           S ./star_output/ERR899423Aligned.out.bam         ||
# ||                                                                            ||
# ||             Output file : ./featureCount_output/ERR899423Aligned.count ... ||
# ||                 Summary : ./featureCount_output/ERR899423Aligned.count ... ||
# ||              Annotation : /fs/project/PAS1307/genomes/Mus_musculus/Ens ... ||
# ||      Dir for temp files : ./featureCount_output                            ||
# ||                                                                            ||
# ||                 Threads : 24                                               ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||         Strand specific : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file /fs/project/PAS1307/genomes/Mus_musculus/Ensembl/ ... ||
# ||    Features : 690647                                                       ||
# ||    Meta-features : 46078                                                   ||
# ||    Chromosomes/contigs : 73                                                ||
# ||                                                                            ||
# || Process BAM file ./star_output/ERR899423Aligned.out.bam...                 ||
# ||    Single-end reads are included.                                          ||
# ||    Assign reads to features...                                             ||
# ||    Total reads : 7567977                                                   ||
# ||    Successfully assigned reads : 4140773 (54.7%)                           ||
# ||    Running time : 0.33 minutes                                             ||
# ||                                                                            ||
# ||                         Read assignment finished.                          ||
# ||                                                                            ||
# || Summary of counting results can be found in file "./featureCount_output/E  ||
# || RR899423Aligned.count.txt.summary"                                         ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v1.6.0
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           S ./star_output/ERR899424Aligned.out.bam         ||
# ||                                                                            ||
# ||             Output file : ./featureCount_output/ERR899424Aligned.count ... ||
# ||                 Summary : ./featureCount_output/ERR899424Aligned.count ... ||
# ||              Annotation : /fs/project/PAS1307/genomes/Mus_musculus/Ens ... ||
# ||      Dir for temp files : ./featureCount_output                            ||
# ||                                                                            ||
# ||                 Threads : 24                                               ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||         Strand specific : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file /fs/project/PAS1307/genomes/Mus_musculus/Ensembl/ ... ||
# ||    Features : 690647                                                       ||
# ||    Meta-features : 46078                                                   ||
# ||    Chromosomes/contigs : 73                                                ||
# ||                                                                            ||
# || Process BAM file ./star_output/ERR899424Aligned.out.bam...                 ||
# ||    Single-end reads are included.                                          ||
# ||    Assign reads to features...                                             ||
# ||    Total reads : 8060973                                                   ||
# ||    Successfully assigned reads : 4075483 (50.6%)                           ||
# ||    Running time : 0.37 minutes                                             ||
# ||                                                                            ||
# ||                         Read assignment finished.                          ||
# ||                                                                            ||
# || Summary of counting results can be found in file "./featureCount_output/E  ||
# || RR899424Aligned.count.txt.summary"                                         ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v1.6.0
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           S ./star_output/ERR899425Aligned.out.bam         ||
# ||                                                                            ||
# ||             Output file : ./featureCount_output/ERR899425Aligned.count ... ||
# ||                 Summary : ./featureCount_output/ERR899425Aligned.count ... ||
# ||              Annotation : /fs/project/PAS1307/genomes/Mus_musculus/Ens ... ||
# ||      Dir for temp files : ./featureCount_output                            ||
# ||                                                                            ||
# ||                 Threads : 24                                               ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||         Strand specific : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file /fs/project/PAS1307/genomes/Mus_musculus/Ensembl/ ... ||
# ||    Features : 690647                                                       ||
# ||    Meta-features : 46078                                                   ||
# ||    Chromosomes/contigs : 73                                                ||
# ||                                                                            ||
# || Process BAM file ./star_output/ERR899425Aligned.out.bam...                 ||
# ||    Single-end reads are included.                                          ||
# ||    Assign reads to features...                                             ||
# ||    Total reads : 8654636                                                   ||
# ||    Successfully assigned reads : 4655774 (53.8%)                           ||
# ||    Running time : 0.38 minutes                                             ||
# ||                                                                            ||
# ||                         Read assignment finished.                          ||
# ||                                                                            ||
# || Summary of counting results can be found in file "./featureCount_output/E  ||
# || RR899425Aligned.count.txt.summary"                                         ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v1.6.0
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           S ./star_output/ERR899426Aligned.out.bam         ||
# ||                                                                            ||
# ||             Output file : ./featureCount_output/ERR899426Aligned.count ... ||
# ||                 Summary : ./featureCount_output/ERR899426Aligned.count ... ||
# ||              Annotation : /fs/project/PAS1307/genomes/Mus_musculus/Ens ... ||
# ||      Dir for temp files : ./featureCount_output                            ||
# ||                                                                            ||
# ||                 Threads : 24                                               ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||         Strand specific : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file /fs/project/PAS1307/genomes/Mus_musculus/Ensembl/ ... ||
# ||    Features : 690647                                                       ||
# ||    Meta-features : 46078                                                   ||
# ||    Chromosomes/contigs : 73                                                ||
# ||                                                                            ||
# || Process BAM file ./star_output/ERR899426Aligned.out.bam...                 ||
# ||    Single-end reads are included.                                          ||
# ||    Assign reads to features...                                             ||
# ||    Total reads : 10659421                                                  ||
# ||    Successfully assigned reads : 4123752 (38.7%)                           ||
# ||    Running time : 0.44 minutes                                             ||
# ||                                                                            ||
# ||                         Read assignment finished.                          ||
# ||                                                                            ||
# || Summary of counting results can be found in file "./featureCount_output/E  ||
# || RR899426Aligned.count.txt.summary"                                         ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v1.6.0
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           S ./star_output/ERR899427Aligned.out.bam         ||
# ||                                                                            ||
# ||             Output file : ./featureCount_output/ERR899427Aligned.count ... ||
# ||                 Summary : ./featureCount_output/ERR899427Aligned.count ... ||
# ||              Annotation : /fs/project/PAS1307/genomes/Mus_musculus/Ens ... ||
# ||      Dir for temp files : ./featureCount_output                            ||
# ||                                                                            ||
# ||                 Threads : 24                                               ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||         Strand specific : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file /fs/project/PAS1307/genomes/Mus_musculus/Ensembl/ ... ||
# ||    Features : 690647                                                       ||
# ||    Meta-features : 46078                                                   ||
# ||    Chromosomes/contigs : 73                                                ||
# ||                                                                            ||
# || Process BAM file ./star_output/ERR899427Aligned.out.bam...                 ||
# ||    Single-end reads are included.                                          ||
# ||    Assign reads to features...                                             ||
# ||    Total reads : 7615582                                                   ||
# ||    Successfully assigned reads : 3890283 (51.1%)                           ||
# ||    Running time : 0.35 minutes                                             ||
# ||                                                                            ||
# ||                         Read assignment finished.                          ||
# ||                                                                            ||
# || Summary of counting results can be found in file "./featureCount_output/E  ||
# || RR899427Aligned.count.txt.summary"                                         ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v1.6.0
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           S ./star_output/ERR899428Aligned.out.bam         ||
# ||                                                                            ||
# ||             Output file : ./featureCount_output/ERR899428Aligned.count ... ||
# ||                 Summary : ./featureCount_output/ERR899428Aligned.count ... ||
# ||              Annotation : /fs/project/PAS1307/genomes/Mus_musculus/Ens ... ||
# ||      Dir for temp files : ./featureCount_output                            ||
# ||                                                                            ||
# ||                 Threads : 24                                               ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||         Strand specific : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file /fs/project/PAS1307/genomes/Mus_musculus/Ensembl/ ... ||
# ||    Features : 690647                                                       ||
# ||    Meta-features : 46078                                                   ||
# ||    Chromosomes/contigs : 73                                                ||
# ||                                                                            ||
# || Process BAM file ./star_output/ERR899428Aligned.out.bam...                 ||
# ||    Single-end reads are included.                                          ||
# ||    Assign reads to features...                                             ||
# ||    Total reads : 7216520                                                   ||
# ||    Successfully assigned reads : 3742170 (51.9%)                           ||
# ||    Running time : 0.34 minutes                                             ||
# ||                                                                            ||
# ||                         Read assignment finished.                          ||
# ||                                                                            ||
# || Summary of counting results can be found in file "./featureCount_output/E  ||
# || RR899428Aligned.count.txt.summary"                                         ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v1.6.0
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           S ./star_output/ERR899429Aligned.out.bam         ||
# ||                                                                            ||
# ||             Output file : ./featureCount_output/ERR899429Aligned.count ... ||
# ||                 Summary : ./featureCount_output/ERR899429Aligned.count ... ||
# ||              Annotation : /fs/project/PAS1307/genomes/Mus_musculus/Ens ... ||
# ||      Dir for temp files : ./featureCount_output                            ||
# ||                                                                            ||
# ||                 Threads : 24                                               ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||         Strand specific : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file /fs/project/PAS1307/genomes/Mus_musculus/Ensembl/ ... ||
# ||    Features : 690647                                                       ||
# ||    Meta-features : 46078                                                   ||
# ||    Chromosomes/contigs : 73                                                ||
# ||                                                                            ||
# || Process BAM file ./star_output/ERR899429Aligned.out.bam...                 ||
# ||    Single-end reads are included.                                          ||
# ||    Assign reads to features...                                             ||
# ||    Total reads : 7814484                                                   ||
# ||    Successfully assigned reads : 4384281 (56.1%)                           ||
# ||    Running time : 0.34 minutes                                             ||
# ||                                                                            ||
# ||                         Read assignment finished.                          ||
# ||                                                                            ||
# || Summary of counting results can be found in file "./featureCount_output/E  ||
# || RR899429Aligned.count.txt.summary"                                         ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v1.6.0
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           S ./star_output/ERR899430Aligned.out.bam         ||
# ||                                                                            ||
# ||             Output file : ./featureCount_output/ERR899430Aligned.count ... ||
# ||                 Summary : ./featureCount_output/ERR899430Aligned.count ... ||
# ||              Annotation : /fs/project/PAS1307/genomes/Mus_musculus/Ens ... ||
# ||      Dir for temp files : ./featureCount_output                            ||
# ||                                                                            ||
# ||                 Threads : 24                                               ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||         Strand specific : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file /fs/project/PAS1307/genomes/Mus_musculus/Ensembl/ ... ||
# ||    Features : 690647                                                       ||
# ||    Meta-features : 46078                                                   ||
# ||    Chromosomes/contigs : 73                                                ||
# ||                                                                            ||
# || Process BAM file ./star_output/ERR899430Aligned.out.bam...                 ||
# ||    Single-end reads are included.                                          ||
# ||    Assign reads to features...                                             ||
# ||    Total reads : 7894117                                                   ||
# ||    Successfully assigned reads : 4250499 (53.8%)                           ||
# ||    Running time : 0.34 minutes                                             ||
# ||                                                                            ||
# ||                         Read assignment finished.                          ||
# ||                                                                            ||
# || Summary of counting results can be found in file "./featureCount_output/E  ||
# || RR899430Aligned.count.txt.summary"                                         ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v1.6.0
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           S ./star_output/ERR899431Aligned.out.bam         ||
# ||                                                                            ||
# ||             Output file : ./featureCount_output/ERR899431Aligned.count ... ||
# ||                 Summary : ./featureCount_output/ERR899431Aligned.count ... ||
# ||              Annotation : /fs/project/PAS1307/genomes/Mus_musculus/Ens ... ||
# ||      Dir for temp files : ./featureCount_output                            ||
# ||                                                                            ||
# ||                 Threads : 24                                               ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||         Strand specific : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file /fs/project/PAS1307/genomes/Mus_musculus/Ensembl/ ... ||
# ||    Features : 690647                                                       ||
# ||    Meta-features : 46078                                                   ||
# ||    Chromosomes/contigs : 73                                                ||
# ||                                                                            ||
# || Process BAM file ./star_output/ERR899431Aligned.out.bam...                 ||
# ||    Single-end reads are included.                                          ||
# ||    Assign reads to features...                                             ||
# ||    Total reads : 7844861                                                   ||
# ||    Successfully assigned reads : 4532529 (57.8%)                           ||
# ||    Running time : 0.34 minutes                                             ||
# ||                                                                            ||
# ||                         Read assignment finished.                          ||
# ||                                                                            ||
# || Summary of counting results can be found in file "./featureCount_output/E  ||
# || RR899431Aligned.count.txt.summary"                                         ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v1.6.0
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           S ./star_output/ERR899432Aligned.out.bam         ||
# ||                                                                            ||
# ||             Output file : ./featureCount_output/ERR899432Aligned.count ... ||
# ||                 Summary : ./featureCount_output/ERR899432Aligned.count ... ||
# ||              Annotation : /fs/project/PAS1307/genomes/Mus_musculus/Ens ... ||
# ||      Dir for temp files : ./featureCount_output                            ||
# ||                                                                            ||
# ||                 Threads : 24                                               ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||         Strand specific : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file /fs/project/PAS1307/genomes/Mus_musculus/Ensembl/ ... ||
# ||    Features : 690647                                                       ||
# ||    Meta-features : 46078                                                   ||
# ||    Chromosomes/contigs : 73                                                ||
# ||                                                                            ||
# || Process BAM file ./star_output/ERR899432Aligned.out.bam...                 ||
# ||    Single-end reads are included.                                          ||
# ||    Assign reads to features...                                             ||
# ||    Total reads : 7213605                                                   ||
# ||    Successfully assigned reads : 4243939 (58.8%)                           ||
# ||    Running time : 0.31 minutes                                             ||
# ||                                                                            ||
# ||                         Read assignment finished.                          ||
# ||                                                                            ||
# || Summary of counting results can be found in file "./featureCount_output/E  ||
# || RR899432Aligned.count.txt.summary"                                         ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v1.6.0
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           S ./star_output/ERR899433Aligned.out.bam         ||
# ||                                                                            ||
# ||             Output file : ./featureCount_output/ERR899433Aligned.count ... ||
# ||                 Summary : ./featureCount_output/ERR899433Aligned.count ... ||
# ||              Annotation : /fs/project/PAS1307/genomes/Mus_musculus/Ens ... ||
# ||      Dir for temp files : ./featureCount_output                            ||
# ||                                                                            ||
# ||                 Threads : 24                                               ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||         Strand specific : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file /fs/project/PAS1307/genomes/Mus_musculus/Ensembl/ ... ||
# ||    Features : 690647                                                       ||
# ||    Meta-features : 46078                                                   ||
# ||    Chromosomes/contigs : 73                                                ||
# ||                                                                            ||
# || Process BAM file ./star_output/ERR899433Aligned.out.bam...                 ||
# ||    Single-end reads are included.                                          ||
# ||    Assign reads to features...                                             ||
# ||    Total reads : 8098199                                                   ||
# ||    Successfully assigned reads : 4533982 (56.0%)                           ||
# ||    Running time : 0.35 minutes                                             ||
# ||                                                                            ||
# ||                         Read assignment finished.                          ||
# ||                                                                            ||
# || Summary of counting results can be found in file "./featureCount_output/E  ||
# || RR899433Aligned.count.txt.summary"                                         ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v1.6.0
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           S ./star_output/ERR899434Aligned.out.bam         ||
# ||                                                                            ||
# ||             Output file : ./featureCount_output/ERR899434Aligned.count ... ||
# ||                 Summary : ./featureCount_output/ERR899434Aligned.count ... ||
# ...
# || Load annotation file /fs/project/PAS1307/genomes/Mus_musculus/Ensembl/ ... ||
# ||    Features : 690647                                                       ||
# ||    Meta-features : 46078                                                   ||
# ||    Chromosomes/contigs : 73                                                ||
# ||                                                                            ||
# || Process BAM file ./star_output/ERR899434Aligned.out.bam...                 ||
# ||    Single-end reads are included.                                          ||
# ||    Assign reads to features...                                             ||
# ||    Total reads : 7816005                                                   ||
# ||    Successfully assigned reads : 4288921 (54.9%)                           ||
# ||    Running time : 0.34 minutes                                             ||
# ||                                                                            ||
# ||                         Read assignment finished.                          ||
# ||                                                                            ||
# || Summary of counting results can be found in file "./featureCount_output/E  ||
# || RR899434Aligned.count.txt.summary"                                         ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v1.6.0
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           S ./star_output/ERR899435Aligned.out.bam         ||
# ||                                                                            ||
# ||             Output file : ./featureCount_output/ERR899435Aligned.count ... ||
# ||                 Summary : ./featureCount_output/ERR899435Aligned.count ... ||
# ||              Annotation : /fs/project/PAS1307/genomes/Mus_musculus/Ens ... ||
# ||      Dir for temp files : ./featureCount_output                            ||
# ||                                                                            ||
# ||                 Threads : 24                                               ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||         Strand specific : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file /fs/project/PAS1307/genomes/Mus_musculus/Ensembl/ ... ||
# ||    Features : 690647                                                       ||
# ||    Meta-features : 46078                                                   ||
# ||    Chromosomes/contigs : 73                                                ||
# ||                                                                            ||
# || Process BAM file ./star_output/ERR899435Aligned.out.bam...                 ||
# ||    Single-end reads are included.                                          ||
# ||    Assign reads to features...                                             ||
# ||    Total reads : 7319465                                                   ||
# ||    Successfully assigned reads : 4091465 (55.9%)                           ||
# ||    Running time : 0.35 minutes                                             ||
# ||                                                                            ||
# ||                         Read assignment finished.                          ||
# ||                                                                            ||
# || Summary of counting results can be found in file "./featureCount_output/E  ||
# || RR899435Aligned.count.txt.summary"                                         ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v1.6.0
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           S ./star_output/ERR899436Aligned.out.bam         ||
# ||                                                                            ||
# ||             Output file : ./featureCount_output/ERR899436Aligned.count ... ||
# ||                 Summary : ./featureCount_output/ERR899436Aligned.count ... ||
# ||              Annotation : /fs/project/PAS1307/genomes/Mus_musculus/Ens ... ||
# ||      Dir for temp files : ./featureCount_output                            ||
# ||                                                                            ||
# ||                 Threads : 24                                               ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||         Strand specific : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file /fs/project/PAS1307/genomes/Mus_musculus/Ensembl/ ... ||
# ||    Features : 690647                                                       ||
# ||    Meta-features : 46078                                                   ||
# ||    Chromosomes/contigs : 73                                                ||
# ||                                                                            ||
# || Process BAM file ./star_output/ERR899436Aligned.out.bam...                 ||
# ||    Single-end reads are included.                                          ||
# ||    Assign reads to features...                                             ||
# ||    Total reads : 7357420                                                   ||
# ||    Successfully assigned reads : 4157877 (56.5%)                           ||
# ||    Running time : 0.32 minutes                                             ||
# ||                                                                            ||
# ||                         Read assignment finished.                          ||
# ||                                                                            ||
# || Summary of counting results can be found in file "./featureCount_output/E  ||
# || RR899436Aligned.count.txt.summary"                                         ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v1.6.0
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           S ./star_output/ERR899437Aligned.out.bam         ||
# ||                                                                            ||
# ||             Output file : ./featureCount_output/ERR899437Aligned.count ... ||
# ||                 Summary : ./featureCount_output/ERR899437Aligned.count ... ||
# ||              Annotation : /fs/project/PAS1307/genomes/Mus_musculus/Ens ... ||
# ||      Dir for temp files : ./featureCount_output                            ||
# ||                                                                            ||
# ||                 Threads : 24                                               ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||         Strand specific : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file /fs/project/PAS1307/genomes/Mus_musculus/Ensembl/ ... ||
# ||    Features : 690647                                                       ||
# ||    Meta-features : 46078                                                   ||
# ||    Chromosomes/contigs : 73                                                ||
# ||                                                                            ||
# || Process BAM file ./star_output/ERR899437Aligned.out.bam...                 ||
# ||    Single-end reads are included.                                          ||
# ||    Assign reads to features...                                             ||
# ||    Total reads : 8847290                                                   ||
# ||    Successfully assigned reads : 4213290 (47.6%)                           ||
# ||    Running time : 0.38 minutes                                             ||
# ||                                                                            ||
# ||                         Read assignment finished.                          ||
# ||                                                                            ||
# || Summary of counting results can be found in file "./featureCount_output/E  ||
# || RR899437Aligned.count.txt.summary"                                         ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v1.6.0
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 1 BAM file                                       ||
# ||                           S ./star_output/ERR899438Aligned.out.bam         ||
# ||                                                                            ||
# ||             Output file : ./featureCount_output/ERR899438Aligned.count ... ||
# ||                 Summary : ./featureCount_output/ERR899438Aligned.count ... ||
# ||              Annotation : /fs/project/PAS1307/genomes/Mus_musculus/Ens ... ||
# ||      Dir for temp files : ./featureCount_output                            ||
# ||                                                                            ||
# ||                 Threads : 24                                               ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||         Strand specific : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file /fs/project/PAS1307/genomes/Mus_musculus/Ensembl/ ... ||
# ||    Features : 690647                                                       ||
# ||    Meta-features : 46078                                                   ||
# ||    Chromosomes/contigs : 73                                                ||
# ||                                                                            ||
# || Process BAM file ./star_output/ERR899438Aligned.out.bam...                 ||
# ||    Single-end reads are included.                                          ||
# ||    Assign reads to features...                                             ||
# ||    Total reads : 9009449                                                   ||
# ||    Successfully assigned reads : 4858518 (53.9%)                           ||
# ||    Running time : 0.39 minutes                                             ||
# ||                                                                            ||
# ||                         Read assignment finished.                          ||
# ||                                                                            ||
# || Summary of counting results can be found in file "./featureCount_output/E  ||
# || RR899438Aligned.count.txt.summary"                                         ||
# ||                                                                            ||
# \\===================== http://subread.sourceforge.net/ ======================//
#
#
# ERROR: invalid parameter: './star_output/ERR899421Aligned.out.bam.out.bam'

# %%
cmd='''
bams=""
for basename in $(find star_output/ -name '*Aligned.out.bam' -exec basename {} \; | cut -f1 -d '.' ); do
    suffix=".out.bam"
    outname="combined.counts.txt"
    bam="$STARDIR/$basename$suffix"    
    bams="$bams $bam"
done

$BINDIR/featureCounts \
        -T $MAXCORES \
        -t exon \
        -g gene_id \
        -a  $GENEANNOTATIONDIR/genes.gtf \
        -o $outname \
        $bams
'''
out=run_cmd(cmd)

# %%
cmd='''
#multiqc of sequencing reads

source activate tophat
multiqc .
'''
out=run_cmd(cmd)

# %%
from IPython.display import FileLinks, display

d = FileLinks(os.environ['WORKDIR'], included_suffixes=['.html'])
e = FileLinks(os.path.join(os.environ['WORKDIR'], os.environ['FASTQCOUT']), included_suffixes=['.html'])
f = FileLinks(os.path.join(os.environ['WORKDIR'], os.environ['TFASTQCOUT']), included_suffixes=['.html'])

display(d)
display(e)
display(f)
# Out:
# /users/PAS1307/osu8805/rnaseq_2/fastQC_output/
#   ERR899423_fastqc.html
#   ERR899424_fastqc.html
#   ERR899428_fastqc.html
#   ERR899427_fastqc.html
#   ERR899421_fastqc.html
#   ERR899435_fastqc.html
#   ERR899432_fastqc.html
#   ERR899422_fastqc.html
#   ERR899436_fastqc.html
#   ERR899434_fastqc.html
#   ERR899430_fastqc.html
#   ERR899437_fastqc.html
#   ERR899426_fastqc.html
#   ERR899429_fastqc.html
#   ERR899431_fastqc.html
#   ERR899433_fastqc.html
#   ERR899425_fastqc.html
#   ERR899438_fastqc.html
# /users/PAS1307/osu8805/rnaseq_2/trimmed_fastQC_output/
#   ERR899427_fastqc.html
#   ERR899428_fastqc.html
#   ERR899430_fastqc.html
#   ERR899421_fastqc.html
#   ERR899423_fastqc.html
#   ERR899432_fastqc.html
#   ERR899422_fastqc.html
#   ERR899435_fastqc.html
#   ERR899424_fastqc.html
#   ERR899436_fastqc.html
#   ERR899434_fastqc.html
#   ERR899437_fastqc.html
#   ERR899429_fastqc.html
#   ERR899431_fastqc.html
#   ERR899426_fastqc.html
#   ERR899433_fastqc.html
#   ERR899425_fastqc.html
#   ERR899438_fastqc.html
#   ERR899428_trimmed_fastqc.html
#   ERR899427_trimmed_fastqc.html
#   ERR899435_trimmed_fastqc.html
#   ERR899421_trimmed_fastqc.html
#   ERR899432_trimmed_fastqc.html
#   ERR899436_trimmed_fastqc.html
#   ERR899434_trimmed_fastqc.html
#   ERR899423_trimmed_fastqc.html
#   ERR899424_trimmed_fastqc.html
#   ERR899437_trimmed_fastqc.html
#   ERR899422_trimmed_fastqc.html
#   ERR899430_trimmed_fastqc.html
#   ERR899426_trimmed_fastqc.html
#   ERR899429_trimmed_fastqc.html
#   ERR899431_trimmed_fastqc.html
#   ERR899433_trimmed_fastqc.html
#   ERR899425_trimmed_fastqc.html
#   ERR899438_trimmed_fastqc.html
# /users/PAS1307/osu8805/rnaseq_2/fastQC_output/
#   ERR899423_fastqc.html
#   ERR899424_fastqc.html
#   ERR899428_fastqc.html
#   ERR899427_fastqc.html
#   ERR899421_fastqc.html
#   ERR899435_fastqc.html
#   ERR899432_fastqc.html
#   ERR899422_fastqc.html
#   ERR899436_fastqc.html
#   ERR899434_fastqc.html
#   ERR899430_fastqc.html
#   ERR899437_fastqc.html
#   ERR899426_fastqc.html
#   ERR899429_fastqc.html
#   ERR899431_fastqc.html
#   ERR899433_fastqc.html
#   ERR899425_fastqc.html
#   ERR899438_fastqc.html
# /users/PAS1307/osu8805/rnaseq_2/trimmed_fastQC_output/
#   ERR899427_fastqc.html
#   ERR899428_fastqc.html
#   ERR899430_fastqc.html
#   ERR899421_fastqc.html
#   ERR899423_fastqc.html
#   ERR899432_fastqc.html
#   ERR899422_fastqc.html
#   ERR899435_fastqc.html
#   ERR899424_fastqc.html
#   ERR899436_fastqc.html
#   ERR899434_fastqc.html
#   ERR899437_fastqc.html
#   ERR899429_fastqc.html
#   ERR899431_fastqc.html
#   ERR899426_fastqc.html
#   ERR899433_fastqc.html
#   ERR899425_fastqc.html
#   ERR899438_fastqc.html
#   ERR899428_trimmed_fastqc.html
#   ERR899427_trimmed_fastqc.html
#   ERR899435_trimmed_fastqc.html
#   ERR899421_trimmed_fastqc.html
#   ERR899432_trimmed_fastqc.html
#   ERR899436_trimmed_fastqc.html
#   ERR899434_trimmed_fastqc.html
#   ERR899423_trimmed_fastqc.html
#   ERR899424_trimmed_fastqc.html
#   ERR899437_trimmed_fastqc.html
#   ERR899422_trimmed_fastqc.html
#   ERR899430_trimmed_fastqc.html
#   ERR899426_trimmed_fastqc.html
#   ERR899429_trimmed_fastqc.html
#   ERR899431_trimmed_fastqc.html
#   ERR899433_trimmed_fastqc.html
#   ERR899425_trimmed_fastqc.html
#   ERR899438_trimmed_fastqc.html
